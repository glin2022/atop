# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "6"

import torch, time, torchattacks, random, argparse
import numpy as np
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from models.resnet import ResNet18, ResNet34, ResNet50
from model.networks import Generator, Discriminator
import utils.misc as misc
import model.losses as gan_losses
import torchvision as tv
import torch.nn as nn
from util import get_mask_list

device = torch.device("cuda")

# 设置seed
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    
seed_everything(777)
image_nc = 3
batch_size = 8
epochs = 300

parser = argparse.ArgumentParser()
parser.add_argument('--config', type=str,
                    default="configs/train.yaml", help="Path to yaml config file")
args = parser.parse_args(args=['--config', 'configs/train.yaml'])
config = misc.get_config(args.config)

checkpoint_dir = 'checkpoint/cifar_tmp'
config.checkpoint_dir = checkpoint_dir
config.batch_size = batch_size
tmp_n = 10
# -----------------------------开始------------------------------

transform_train = transforms.Compose([
     transforms.Resize(256),
     transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
])

transform_test = transforms.Compose([
     transforms.Resize(256),
     transforms.ToTensor(),
])

train_set = datasets.CIFAR10("../../data", download=True, transform=transform_train)
test_set = datasets.CIFAR10("../../data", download=True, transform=transform_test, train=False)


train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=8)

discriminator = Discriminator(cnum_in=4, cnum=64)
discriminator = discriminator.to(device)


class Model_g(nn.Module):
    def __init__(self):
        super(Model_g, self).__init__()
        
        sd_path = 'pretrained/states_pt_places2.pth'
        self.generator = Generator(cnum_in=5, cnum=48, return_flow=False, checkpoint=sd_path)
        self.generator.train()
        
        self.res = ResNet18()
        self.res.load_state_dict(torch.load('./models/state_dicts/resnet18_cifar_932.pth'))
        self.res.eval()
    
    def forward(self, x, adv_x, mask, test_flag):
        x1, x2 = self.generator(x, mask)
        if not test_flag:
            adv_x1, adv_x2 = self.generator(adv_x, mask)
            outputs_cls = self.res(adv_x2)
        else: outputs_cls = self.res(x2)
            
        batch_complete = x2
        return x1, x2, batch_complete, outputs_cls

# 冻结resnet的参数
model = Model_g().to(device)
for param in model.named_parameters():
    if 'res' in param[0]:
        param[1].requires_grad = False
        
model_res = ResNet18().to(device)
model_res.load_state_dict(torch.load('./models/state_dicts/resnet18_cifar_932.pth'))
model_res.eval()

g_optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()), lr=config.g_lr, betas=(config.g_beta1, config.g_beta2))
d_optimizer = torch.optim.Adam(
    discriminator.parameters(), lr=config.d_lr, betas=(config.d_beta1, config.d_beta2))


# 加载损失函数
gan_loss_d, gan_loss_g = gan_losses.hinge_loss_d, gan_losses.hinge_loss_g
loss_fun = torch.nn.CrossEntropyLoss()

# 使用tensorboard进行可视化统计
if config.tb_logging:
    from torch.utils.tensorboard import SummaryWriter
    writer = SummaryWriter(config.log_dir)

    

# 正式开始训练模型    
losses = {}

# generator.train()
discriminator.train()

last_n_iter = -1
losses_log = {'d_loss':   [],
              'g_loss':   [],
              'ae_loss':  [],
              'ae_loss1': [],
              'ae_loss2': [],
              'cls_loss': [],
              }

# training loop
init_n_iter = last_n_iter + 1
n_iter = 0
time0 = time.time()

block_n = 32
gau_n = 0.25
missing_rate = 0.25
cls_n = 0.05
atk1 = torchattacks.FGSM(model_res, eps=8/255.)
atk2 = torchattacks.BIM(model_res, eps=8/255.)
atk3 = torchattacks.EOTPGD(model_res, eps=8/255.)
atk4 = torchattacks.PGD(model_res, eps=8/255., steps=20)
for epoch in range(1, epochs+1):
    train_acc = 0
    
    for i, data in enumerate(train_loader, 0):
        batch_real, labels = data
        batch_real, labels = batch_real.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        # 加入高斯噪声
        batch_adv = atk1(batch_real, labels)
        gau_noise = torch.normal(0, 1, batch_real.shape)*gau_n
        gau_noise = gau_noise.to(device)
        batch_gau = torch.clip((batch_real+gau_noise), 0, 1)
        adv_gau = torch.clip((batch_adv+gau_noise), 0, 1)
        batch_gau.mul_(2).sub_(1)
            
        adv_gau.mul_(2).sub_(1)
        batch_real.mul_(2).sub_(1)
        
        # 生成mask
        nums = np.zeros(int((256**2) / (block_n**2)))
        nums[:int(missing_rate*(len(nums)))] = 1
        np.random.shuffle(nums)
        mask = nums.reshape((1,1,int(256/block_n),int(256/block_n)))
        
        
        mask = np.repeat(mask, block_n, axis=2)
        mask = np.repeat(mask, block_n, axis=3)
         
        mask = torch.from_numpy(mask).type(torch.float).to(device)
        
        batch_incomplete = batch_gau*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        
        adv_incomplete = adv_gau*(1.-mask)
        adv_ones_x = torch.ones_like(adv_incomplete)[:, 0:1, :, :].to(device)
        adv_x = torch.cat([adv_incomplete, adv_ones_x, adv_ones_x*mask], axis=1)
        
        # x1为coarse result，x2为refined result
        x1, x2, batch_complete, outputs_cls = model(x, adv_x, mask, False)
        batch_predicted = x2.clone().detach()
        batch_complete = x2.clone().detach()
        
        
        loss_cls = loss_fun(outputs_cls, labels)
        losses['cls_loss'] = loss_cls
        
        # 开始关于D的训练：
        batch_real_mask = torch.cat(
            (batch_real, torch.tile(mask, [config.batch_size, 1, 1, 1])), dim=1)
        batch_filled_mask = torch.cat((batch_complete.detach(), torch.tile(
            mask, [config.batch_size, 1, 1, 1])), dim=1)

        batch_real_filled = torch.cat((batch_real_mask, batch_filled_mask))

        d_real_gen = discriminator(batch_real_filled)
        d_real, d_gen = torch.split(d_real_gen, config.batch_size)

        d_loss = gan_loss_d(d_real, d_gen)
        losses['d_loss'] = d_loss

        # update D parameters
        d_optimizer.zero_grad()
        losses['d_loss'].backward()
        d_optimizer.step()

        
        # 开始关于G的训练
        losses['ae_loss1'] = config.l1_loss_alpha * \
            torch.mean((torch.abs(batch_real - x1)))
        losses['ae_loss2'] = config.l1_loss_alpha * \
            torch.mean((torch.abs(batch_real - x2)))
        losses['ae_loss'] = losses['ae_loss1'] + losses['ae_loss2']

        batch_gen = batch_predicted
        batch_gen = torch.cat((batch_gen, torch.tile(
            mask, [config.batch_size, 1, 1, 1])), dim=1)

        d_gen = discriminator(batch_gen)

        g_loss = gan_loss_g(d_gen)
        losses['g_loss'] = g_loss
        losses['g_loss'] = config.gan_loss_alpha * losses['g_loss']
        if config.ae_loss:
            losses['g_loss'] += losses['ae_loss']
            if epoch > 2: losses['g_loss'] += losses['cls_loss']*cls_n

        # update G parameters
        g_optimizer.zero_grad()
        losses['g_loss'].backward()
        g_optimizer.step()
        
        # LOGGING
        for k in losses_log.keys():
            losses_log[k].append(losses[k].item())

        # (tensorboard) logging
        if n_iter % config.print_iter == 0:
            # measure iterations/second
            dt = time.time() - time0
            print(f"@iter: {n_iter}: {(config.print_iter/dt):.4f} it/s")
            time0 = time.time()

            # write loss terms to console
            # and tensorboard
            for k, loss_log in losses_log.items():
                loss_log_mean = sum(loss_log)/len(loss_log)
                print(f"{k}: {loss_log_mean:.4f}")
                if config.tb_logging:
                    writer.add_scalar(
                        f"losses/{k}", loss_log_mean, global_step=n_iter)                
                losses_log[k].clear()

        # save example image grids to tensorboard
        if config.tb_logging \
            and config.save_imgs_to_tb_iter \
            and n_iter % config.save_imgs_to_tb_iter == 0:
            viz_images = [misc.pt_to_image(batch_complete),
                          misc.pt_to_image(x1), misc.pt_to_image(x2)]
            img_grids = [tv.utils.make_grid(images[:config.viz_max_out], nrow=2)
                        for images in viz_images]

            writer.add_image(
                "Inpainted", img_grids[0], global_step=n_iter, dataformats="CHW")
            writer.add_image(
                "Stage 1", img_grids[1], global_step=n_iter, dataformats="CHW")
            writer.add_image(
                "Stage 2", img_grids[2], global_step=n_iter, dataformats="CHW")

        # save example image grids to disk
        if config.save_imgs_to_disc_iter \
            and n_iter % config.save_imgs_to_disc_iter == 0:
            viz_images = [misc.pt_to_image(batch_real), 
                          misc.pt_to_image(batch_complete)]
            img_grids = [tv.utils.make_grid(images[:config.viz_max_out], nrow=2)
                                            for images in viz_images]
            tv.utils.save_image(img_grids, 
            f"{checkpoint_dir}/iter_{tmp_n}_{n_iter}.png", 
            nrow=2)

        # save state dict snapshot
        if n_iter % config.save_checkpoint_iter == 0 \
            and n_iter > init_n_iter:
            misc.save_states(f"states_{tmp_n}.pth",
                        model, discriminator,
                        g_optimizer, d_optimizer,
                        n_iter, config)
        # save state dict snapshot backup
        if config.save_cp_backup_iter \
            and n_iter % config.save_cp_backup_iter == 0 \
            and n_iter > init_n_iter:
            misc.save_states(f"states_{tmp_n}_{n_iter}.pth",
                        model, discriminator,
                        g_optimizer, d_optimizer,
                        n_iter, config)
        n_iter += 1
        if i==624: break
        
    acc=0
    acc_atk1=0
    acc_atk2=0
    acc_atk3=0
    acc_atk4=0
    for i, data in enumerate(test_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        adv_inputs1 = atk1(inputs, labels)
        adv_inputs2 = atk2(inputs, labels)
        adv_inputs3 = atk3(inputs, labels)
        adv_inputs4 = atk4(inputs, labels)

        gau_noise = torch.normal(0, 1, inputs.shape)*gau_n
        gau_noise = gau_noise.to(device)
        
        inputs_gau = torch.clip((inputs+gau_noise), 0, 1)
        adv_gau1 = torch.clip((adv_inputs1+gau_noise), 0, 1)
        adv_gau2 = torch.clip((adv_inputs2+gau_noise), 0, 1)
        adv_gau3 = torch.clip((adv_inputs3+gau_noise), 0, 1)
        adv_gau4 = torch.clip((adv_inputs4+gau_noise), 0, 1)
        
        
        inputs_gau.mul_(2).sub_(1)
        adv_gau1.mul_(2).sub_(1)
        adv_gau2.mul_(2).sub_(1)
        adv_gau3.mul_(2).sub_(1)
        adv_gau4.mul_(2).sub_(1)
        
        # 生成mask
        nums = np.zeros(int((256**2) / (block_n**2)))
        nums[:int(missing_rate*(len(nums)))] = 1
        np.random.shuffle(nums)
        mask = nums.reshape((1,1,int(256/block_n),int(256/block_n)))
        
        mask = np.repeat(mask, block_n, axis=2)
        mask = np.repeat(mask, block_n, axis=3)
         
        mask = torch.from_numpy(mask).type(torch.float).to(device)
        
        batch_incomplete = inputs_gau*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        x1, x2, batch_complete, outputs_cls = model(x, x, mask, True)
        inputs_predicted = x2.clone().detach()
        
        batch_incomplete = adv_gau1*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        x1, x2, batch_complete, outputs_cls = model(x, x, mask, True)
        adv_predicted1 = x2.clone().detach()
        
        batch_incomplete = adv_gau2*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        x1, x2, batch_complete, outputs_cls = model(x, x, mask, True)
        adv_predicted2 = x2.clone().detach()
        
        batch_incomplete = adv_gau3*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        x1, x2, batch_complete, outputs_cls = model(x, x, mask, True)
        adv_predicted3 = x2.clone().detach()
        
        batch_incomplete = adv_gau4*(1.-mask)
        ones_x = torch.ones_like(batch_incomplete)[:, 0:1, :, :].to(device)
        x = torch.cat([batch_incomplete, ones_x, ones_x*mask], axis=1)
        x1, x2, batch_complete, outputs_cls = model(x, x, mask, True)
        adv_predicted4 = x2.clone().detach()

        
        _, preds = torch.max(model_res(inputs_predicted), 1)
        _, preds_atk1 = torch.max(model_res(adv_predicted1), 1)
        _, preds_atk2 = torch.max(model_res(adv_predicted2), 1)
        _, preds_atk3 = torch.max(model_res(adv_predicted3), 1)
        _, preds_atk4 = torch.max(model_res(adv_predicted4), 1)

        acc += torch.sum(preds == labels).item()
        acc_atk1 += torch.sum(preds_atk1 == labels).item()
        acc_atk2 += torch.sum(preds_atk2 == labels).item()
        acc_atk3 += torch.sum(preds_atk3 == labels).item()
        acc_atk4 += torch.sum(preds_atk4 == labels).item()
        if i == 63: break

    print("test acc on clean examples (%): {:.2f}".format(
            (acc / 512.) * 100.0))
    print("test acc on FGSM examples (%):  {:.2f}".format(
            (acc_atk1 / 512.) * 100.0))
    print("test acc on BIM examples (%):   {:.2f}".format(
            (acc_atk2 / 512.) * 100.0))
    print("test acc on EoT examples (%):   {:.2f}".format(
            (acc_atk3 / 512.) * 100.0))
    print("test acc on BPDA examples (%):  {:.2f}".format(
            (acc_atk4 / 512.) * 100.0))
    print('________epoch '+str(epoch)+'________')
    misc.save_states(f"states_{tmp_n}_{epoch}.pth",
                    model, discriminator,
                    g_optimizer, d_optimizer,
                    epoch, config)
# Out:
# /home/lin/anaconda3/envs/py38_101/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/lin/anaconda3/envs/py38_101/lib/python3.8/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# Files already downloaded and verified
# Files already downloaded and verified
# @iter: 0: 32.0716 it/s
# d_loss: 1.0004
# g_loss: 0.4020
# ae_loss: 0.4109
# ae_loss1: 0.1552
# ae_loss2: 0.2558
# cls_loss: 2.8541
# @iter: 100: 1.3900 it/s
# d_loss: 0.9992
# g_loss: 0.0541
# ae_loss: 0.1281
# ae_loss1: 0.0582
# ae_loss2: 0.0699
# cls_loss: 1.6255
# Saved state dicts!
# @iter: 200: 1.4268 it/s
# d_loss: 0.9903
# g_loss: 0.0994
# ae_loss: 0.0950
# ae_loss1: 0.0461
# ae_loss2: 0.0489
# cls_loss: 1.0380
# Saved state dicts!
# @iter: 300: 1.4271 it/s
# d_loss: 0.9658
# g_loss: 0.2570
# ae_loss: 0.0918
# ae_loss1: 0.0447
# ae_loss2: 0.0471
# cls_loss: 0.7819
# Saved state dicts!
# @iter: 400: 1.4124 it/s
# d_loss: 0.9270
# g_loss: -0.0245
# ae_loss: 0.0888
# ae_loss1: 0.0433
# ae_loss2: 0.0456
# cls_loss: 0.8451
# Saved state dicts!
# @iter: 500: 1.3872 it/s
# d_loss: 0.9264
# g_loss: 0.4548
# ae_loss: 0.0871
# ae_loss1: 0.0425
# ae_loss2: 0.0446
# cls_loss: 0.7750
# Saved state dicts!
# @iter: 600: 1.2979 it/s
# d_loss: 0.9246
# g_loss: 0.4399
# ae_loss: 0.0874
# ae_loss1: 0.0428
# ae_loss2: 0.0445
# cls_loss: 0.7078
# Saved state dicts!
# test acc on clean examples (%): 82.81
# test acc on FGSM examples (%):  64.06
# test acc on BIM examples (%):   70.12
# test acc on EoT examples (%):   71.88
# test acc on BPDA examples (%):  70.51
# ________epoch 1________
# Saved state dicts!
# @iter: 700: 0.4852 it/s
# d_loss: 0.8984
# g_loss: -0.0743
# ae_loss: 0.0849
# ae_loss1: 0.0418
# ae_loss2: 0.0432
# cls_loss: 0.7223
# Saved state dicts!
# @iter: 800: 1.3672 it/s
# d_loss: 0.8681
# g_loss: 0.0358
# ae_loss: 0.0852
# ae_loss1: 0.0418
# ae_loss2: 0.0433
# cls_loss: 0.6993
# Saved state dicts!
# @iter: 900: 1.4071 it/s
# d_loss: 0.8637
# g_loss: 0.1087
# ae_loss: 0.0855
# ae_loss1: 0.0422
# ae_loss2: 0.0433
# cls_loss: 0.7311
# Saved state dicts!
# @iter: 1000: 1.4436 it/s
# d_loss: 0.8759
# g_loss: 0.1482
# ae_loss: 0.0829
# ae_loss1: 0.0409
# ae_loss2: 0.0421
# cls_loss: 0.7511
# Saved state dicts!
# @iter: 1100: 1.4162 it/s
# d_loss: 0.8711
# g_loss: 0.1445
# ae_loss: 0.0828
# ae_loss1: 0.0409
# ae_loss2: 0.0419
# cls_loss: 0.7137
# Saved state dicts!
# @iter: 1200: 1.4503 it/s
# d_loss: 0.8674
# g_loss: 0.1524
# ae_loss: 0.0842
# ae_loss1: 0.0416
# ae_loss2: 0.0427
# cls_loss: 0.7172
# Saved state dicts!
# test acc on clean examples (%): 87.50
# test acc on FGSM examples (%):  67.38
# test acc on BIM examples (%):   74.41
# test acc on EoT examples (%):   77.73
# test acc on BPDA examples (%):  77.54
# ________epoch 2________
# Saved state dicts!
# @iter: 1300: 0.4883 it/s
# d_loss: 0.8523
# g_loss: 0.1394
# ae_loss: 0.0944
# ae_loss1: 0.0444
# ae_loss2: 0.0500
# cls_loss: 0.5795
# Saved state dicts!
# @iter: 1400: 1.1813 it/s
# d_loss: 0.8464
# g_loss: 0.1768
# ae_loss: 0.0946
# ae_loss1: 0.0440
# ae_loss2: 0.0506
# cls_loss: 0.3302
# Saved state dicts!
# @iter: 1500: 1.1141 it/s
# d_loss: 0.8376
# g_loss: 0.1459
# ae_loss: 0.0921
# ae_loss1: 0.0430
# ae_loss2: 0.0491
# cls_loss: 0.2260
# Saved state dicts!
# @iter: 1600: 1.1452 it/s
# d_loss: 0.8564
# g_loss: 0.1901
# ae_loss: 0.0919
# ae_loss1: 0.0432
# ae_loss2: 0.0487
# cls_loss: 0.2316
# Saved state dicts!
# @iter: 1700: 1.2116 it/s
# d_loss: 0.7948
# g_loss: 0.0158
# ae_loss: 0.0923
# ae_loss1: 0.0435
# ae_loss2: 0.0488
# cls_loss: 0.2646
# Saved state dicts!
# @iter: 1800: 1.2249 it/s
# d_loss: 0.7881
# g_loss: 0.0687
# ae_loss: 0.0895
# ae_loss1: 0.0424
# ae_loss2: 0.0471
# cls_loss: 0.2161
# Saved state dicts!
# test acc on clean examples (%): 83.20
# test acc on FGSM examples (%):  82.62
# test acc on BIM examples (%):   79.88
# test acc on EoT examples (%):   80.08
# test acc on BPDA examples (%):  80.86
# ________epoch 3________
# Saved state dicts!
# @iter: 1900: 0.4630 it/s
# d_loss: 0.8019
# g_loss: 0.0801
# ae_loss: 0.0896
# ae_loss1: 0.0420
# ae_loss2: 0.0476
# cls_loss: 0.2282
# Saved state dicts!
# @iter: 2000: 1.2021 it/s
# d_loss: 0.7892
# g_loss: 0.0651
# ae_loss: 0.0897
# ae_loss1: 0.0422
# ae_loss2: 0.0475
# cls_loss: 0.2482
# Saved state dicts!
# @iter: 2100: 1.1836 it/s
# d_loss: 0.7889
# g_loss: 0.0782
# ae_loss: 0.0885
# ae_loss1: 0.0418
# ae_loss2: 0.0467
# cls_loss: 0.2533
# Saved state dicts!
# @iter: 2200: 1.2072 it/s
# d_loss: 0.7977
# g_loss: 0.0595
# ae_loss: 0.0870
# ae_loss1: 0.0413
# ae_loss2: 0.0456
# cls_loss: 0.1638
# Saved state dicts!
# @iter: 2300: 1.1992 it/s
# d_loss: 0.7942
# g_loss: 0.0652
# ae_loss: 0.0883
# ae_loss1: 0.0420
# ae_loss2: 0.0463
# cls_loss: 0.1804
# Saved state dicts!
# @iter: 2400: 1.2182 it/s
# d_loss: 0.7910
# g_loss: 0.0677
# ae_loss: 0.0894
# ae_loss1: 0.0423
# ae_loss2: 0.0471
# cls_loss: 0.2003
# Saved state dicts!
# test acc on clean examples (%): 87.30
# test acc on FGSM examples (%):  88.09
# test acc on BIM examples (%):   84.96
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  84.38
# ________epoch 4________
# Saved state dicts!
# @iter: 2500: 0.4508 it/s
# d_loss: 0.7891
# g_loss: 0.0672
# ae_loss: 0.0884
# ae_loss1: 0.0420
# ae_loss2: 0.0464
# cls_loss: 0.2163
# Saved state dicts!
# @iter: 2600: 1.1080 it/s
# d_loss: 0.7892
# g_loss: 0.0568
# ae_loss: 0.0884
# ae_loss1: 0.0419
# ae_loss2: 0.0464
# cls_loss: 0.2023
# Saved state dicts!
# @iter: 2700: 1.0935 it/s
# d_loss: 0.7944
# g_loss: 0.0633
# ae_loss: 0.0874
# ae_loss1: 0.0417
# ae_loss2: 0.0456
# cls_loss: 0.1689
# Saved state dicts!
# @iter: 2800: 1.1477 it/s
# d_loss: 0.7881
# g_loss: 0.0593
# ae_loss: 0.0883
# ae_loss1: 0.0420
# ae_loss2: 0.0463
# cls_loss: 0.2461
# Saved state dicts!
# @iter: 2900: 1.0975 it/s
# d_loss: 0.7827
# g_loss: 0.0578
# ae_loss: 0.0881
# ae_loss1: 0.0420
# ae_loss2: 0.0461
# cls_loss: 0.2031
# Saved state dicts!
# @iter: 3000: 1.1653 it/s
# d_loss: 0.7700
# g_loss: 0.0429
# ae_loss: 0.0872
# ae_loss1: 0.0415
# ae_loss2: 0.0457
# cls_loss: 0.1788
# Saved state dicts!
# @iter: 3100: 1.1468 it/s
# d_loss: 0.7795
# g_loss: 0.0526
# ae_loss: 0.0871
# ae_loss1: 0.0416
# ae_loss2: 0.0456
# cls_loss: 0.1854
# Saved state dicts!
# test acc on clean examples (%): 89.06
# test acc on FGSM examples (%):  88.09
# test acc on BIM examples (%):   86.72
# test acc on EoT examples (%):   87.11
# test acc on BPDA examples (%):  85.94
# ________epoch 5________
# Saved state dicts!
# @iter: 3200: 0.4294 it/s
# d_loss: 0.7854
# g_loss: 0.0411
# ae_loss: 0.0871
# ae_loss1: 0.0414
# ae_loss2: 0.0457
# cls_loss: 0.2230
# Saved state dicts!
# @iter: 3300: 1.0997 it/s
# d_loss: 0.7931
# g_loss: 0.0448
# ae_loss: 0.0886
# ae_loss1: 0.0421
# ae_loss2: 0.0465
# cls_loss: 0.1894
# Saved state dicts!
# @iter: 3400: 1.1804 it/s
# d_loss: 0.7972
# g_loss: 0.0430
# ae_loss: 0.0869
# ae_loss1: 0.0414
# ae_loss2: 0.0455
# cls_loss: 0.1820
# Saved state dicts!
# @iter: 3500: 1.1242 it/s
# d_loss: 0.7968
# g_loss: 0.0418
# ae_loss: 0.0868
# ae_loss1: 0.0414
# ae_loss2: 0.0454
# cls_loss: 0.1743
# Saved state dicts!
# @iter: 3600: 1.1286 it/s
# d_loss: 0.7959
# g_loss: 0.0436
# ae_loss: 0.0864
# ae_loss1: 0.0412
# ae_loss2: 0.0452
# cls_loss: 0.1762
# Saved state dicts!
# @iter: 3700: 1.1068 it/s
# d_loss: 0.7888
# g_loss: 0.0466
# ae_loss: 0.0868
# ae_loss1: 0.0414
# ae_loss2: 0.0454
# cls_loss: 0.1822
# Saved state dicts!
# test acc on clean examples (%): 85.94
# test acc on FGSM examples (%):  86.33
# test acc on BIM examples (%):   83.40
# test acc on EoT examples (%):   82.42
# test acc on BPDA examples (%):  81.45
# ________epoch 6________
# Saved state dicts!
# @iter: 3800: 0.4376 it/s
# d_loss: 0.7770
# g_loss: 0.0422
# ae_loss: 0.0864
# ae_loss1: 0.0413
# ae_loss2: 0.0451
# cls_loss: 0.1941
# Saved state dicts!
# @iter: 3900: 1.1380 it/s
# d_loss: 0.7737
# g_loss: 0.0464
# ae_loss: 0.0864
# ae_loss1: 0.0412
# ae_loss2: 0.0452
# cls_loss: 0.1577
# Saved state dicts!
# @iter: 4000: 1.1662 it/s
# d_loss: 0.7725
# g_loss: 0.0418
# ae_loss: 0.0884
# ae_loss1: 0.0424
# ae_loss2: 0.0460
# cls_loss: 0.1821
# Saved state dicts!
# @iter: 4100: 1.1568 it/s
# d_loss: 0.7796
# g_loss: 0.0356
# ae_loss: 0.0858
# ae_loss1: 0.0408
# ae_loss2: 0.0449
# cls_loss: 0.2048
# Saved state dicts!
# @iter: 4200: 1.1890 it/s
# d_loss: 0.7625
# g_loss: 0.0323
# ae_loss: 0.0851
# ae_loss1: 0.0405
# ae_loss2: 0.0446
# cls_loss: 0.1528
# Saved state dicts!
# @iter: 4300: 1.1308 it/s
# d_loss: 0.7408
# g_loss: 0.0262
# ae_loss: 0.0868
# ae_loss1: 0.0415
# ae_loss2: 0.0453
# cls_loss: 0.1700
# Saved state dicts!
# test acc on clean examples (%): 85.74
# test acc on FGSM examples (%):  85.74
# test acc on BIM examples (%):   83.20
# test acc on EoT examples (%):   82.62
# test acc on BPDA examples (%):  81.25
# ________epoch 7________
# Saved state dicts!
# @iter: 4400: 0.4671 it/s
# d_loss: 0.7516
# g_loss: 0.0182
# ae_loss: 0.0862
# ae_loss1: 0.0411
# ae_loss2: 0.0451
# cls_loss: 0.1870
# Saved state dicts!
# @iter: 4500: 1.1542 it/s
# d_loss: 0.7335
# g_loss: 0.0311
# ae_loss: 0.0869
# ae_loss1: 0.0416
# ae_loss2: 0.0453
# cls_loss: 0.1609
# Saved state dicts!
# @iter: 4600: 1.0770 it/s
# d_loss: 0.7283
# g_loss: 0.0386
# ae_loss: 0.0863
# ae_loss1: 0.0413
# ae_loss2: 0.0450
# cls_loss: 0.1717
# Saved state dicts!
# @iter: 4700: 1.0912 it/s
# d_loss: 0.7392
# g_loss: 0.0356
# ae_loss: 0.0865
# ae_loss1: 0.0415
# ae_loss2: 0.0450
# cls_loss: 0.1689
# Saved state dicts!
# @iter: 4800: 1.1709 it/s
# d_loss: 0.7476
# g_loss: 0.0315
# ae_loss: 0.0853
# ae_loss1: 0.0408
# ae_loss2: 0.0445
# cls_loss: 0.1588
# Saved state dicts!
# @iter: 4900: 1.1379 it/s
# d_loss: 0.7425
# g_loss: 0.0290
# ae_loss: 0.0860
# ae_loss1: 0.0412
# ae_loss2: 0.0448
# cls_loss: 0.1869
# Saved state dicts!
# test acc on clean examples (%): 86.72
# test acc on FGSM examples (%):  85.94
# test acc on BIM examples (%):   83.40
# test acc on EoT examples (%):   83.01
# test acc on BPDA examples (%):  82.62
# ________epoch 8________
# Saved state dicts!
# @iter: 5000: 0.4283 it/s
# d_loss: 0.7289
# g_loss: 0.0291
# ae_loss: 0.0854
# ae_loss1: 0.0408
# ae_loss2: 0.0446
# cls_loss: 0.1655
# Saved state dicts!
# Saved state dicts!
# @iter: 5100: 1.1716 it/s
# d_loss: 0.7312
# g_loss: 0.0285
# ae_loss: 0.0863
# ae_loss1: 0.0414
# ae_loss2: 0.0449
# cls_loss: 0.1551
# Saved state dicts!
# @iter: 5200: 1.1167 it/s
# d_loss: 0.7358
# g_loss: 0.0246
# ae_loss: 0.0856
# ae_loss1: 0.0409
# ae_loss2: 0.0447
# cls_loss: 0.1544
# Saved state dicts!
# @iter: 5300: 1.1004 it/s
# d_loss: 0.7500
# g_loss: 0.0202
# ae_loss: 0.0851
# ae_loss1: 0.0404
# ae_loss2: 0.0447
# cls_loss: 0.1658
# Saved state dicts!
# @iter: 5400: 1.1502 it/s
# d_loss: 0.7522
# g_loss: 0.0173
# ae_loss: 0.0865
# ae_loss1: 0.0415
# ae_loss2: 0.0450
# cls_loss: 0.1701
# Saved state dicts!
# @iter: 5500: 1.1849 it/s
# d_loss: 0.7563
# g_loss: 0.0063
# ae_loss: 0.0855
# ae_loss1: 0.0410
# ae_loss2: 0.0445
# cls_loss: 0.1648
# Saved state dicts!
# @iter: 5600: 1.0909 it/s
# d_loss: 0.7535
# g_loss: 0.0084
# ae_loss: 0.0852
# ae_loss1: 0.0409
# ae_loss2: 0.0443
# cls_loss: 0.1590
# Saved state dicts!
# test acc on clean examples (%): 87.89
# test acc on FGSM examples (%):  87.70
# test acc on BIM examples (%):   86.13
# test acc on EoT examples (%):   85.55
# test acc on BPDA examples (%):  85.55
# ________epoch 9________
# Saved state dicts!
# @iter: 5700: 0.4361 it/s
# d_loss: 0.7616
# g_loss: -0.0041
# ae_loss: 0.0857
# ae_loss1: 0.0411
# ae_loss2: 0.0446
# cls_loss: 0.1550
# Saved state dicts!
# @iter: 5800: 1.2015 it/s
# d_loss: 0.7524
# g_loss: 0.0024
# ae_loss: 0.0859
# ae_loss1: 0.0411
# ae_loss2: 0.0448
# cls_loss: 0.1647
# Saved state dicts!
# @iter: 5900: 1.1765 it/s
# d_loss: 0.7599
# g_loss: -0.0065
# ae_loss: 0.0846
# ae_loss1: 0.0405
# ae_loss2: 0.0441
# cls_loss: 0.1413
# Saved state dicts!
# @iter: 6000: 1.1119 it/s
# d_loss: 0.7588
# g_loss: -0.0062
# ae_loss: 0.0859
# ae_loss1: 0.0407
# ae_loss2: 0.0452
# cls_loss: 0.1763
# Saved state dicts!
# @iter: 6100: 1.0813 it/s
# d_loss: 0.7610
# g_loss: -0.0071
# ae_loss: 0.0863
# ae_loss1: 0.0409
# ae_loss2: 0.0454
# cls_loss: 0.1979
# Saved state dicts!
# @iter: 6200: 1.1347 it/s
# d_loss: 0.7542
# g_loss: -0.0055
# ae_loss: 0.0862
# ae_loss1: 0.0411
# ae_loss2: 0.0451
# cls_loss: 0.1790
# Saved state dicts!
# test acc on clean examples (%): 84.57
# test acc on FGSM examples (%):  85.16
# test acc on BIM examples (%):   83.98
# test acc on EoT examples (%):   83.20
# test acc on BPDA examples (%):  82.81
# ________epoch 10________
# Saved state dicts!
# @iter: 6300: 0.4196 it/s
# d_loss: 0.7540
# g_loss: -0.0123
# ae_loss: 0.0855
# ae_loss1: 0.0408
# ae_loss2: 0.0447
# cls_loss: 0.1363
# Saved state dicts!
# @iter: 6400: 1.1335 it/s
# d_loss: 0.7611
# g_loss: -0.0192
# ae_loss: 0.0852
# ae_loss1: 0.0407
# ae_loss2: 0.0445
# cls_loss: 0.1560
# Saved state dicts!
# @iter: 6500: 1.1207 it/s
# d_loss: 0.7575
# g_loss: -0.0321
# ae_loss: 0.0841
# ae_loss1: 0.0402
# ae_loss2: 0.0439
# cls_loss: 0.1285
# Saved state dicts!
# @iter: 6600: 1.0864 it/s
# d_loss: 0.7566
# g_loss: -0.0290
# ae_loss: 0.0837
# ae_loss1: 0.0400
# ae_loss2: 0.0437
# cls_loss: 0.1510
# Saved state dicts!
# @iter: 6700: 1.0848 it/s
# d_loss: 0.7503
# g_loss: -0.0336
# ae_loss: 0.0863
# ae_loss1: 0.0412
# ae_loss2: 0.0451
# cls_loss: 0.1646
# Saved state dicts!
# @iter: 6800: 1.0896 it/s
# d_loss: 0.7526
# g_loss: -0.0343
# ae_loss: 0.0858
# ae_loss1: 0.0412
# ae_loss2: 0.0446
# cls_loss: 0.1819
# Saved state dicts!
# test acc on clean examples (%): 89.26
# test acc on FGSM examples (%):  87.50
# test acc on BIM examples (%):   86.13
# test acc on EoT examples (%):   86.33
# test acc on BPDA examples (%):  84.57
# ________epoch 11________
# Saved state dicts!
# @iter: 6900: 0.4095 it/s
# d_loss: 0.7438
# g_loss: -0.0462
# ae_loss: 0.0853
# ae_loss1: 0.0408
# ae_loss2: 0.0445
# cls_loss: 0.1690
# Saved state dicts!
# @iter: 7000: 1.1059 it/s
# d_loss: 0.7487
# g_loss: -0.0515
# ae_loss: 0.0852
# ae_loss1: 0.0410
# ae_loss2: 0.0442
# cls_loss: 0.1507
# Saved state dicts!
# @iter: 7100: 1.0739 it/s
# d_loss: 0.7417
# g_loss: -0.0499
# ae_loss: 0.0846
# ae_loss1: 0.0405
# ae_loss2: 0.0441
# cls_loss: 0.1723
# Saved state dicts!
# @iter: 7200: 1.1008 it/s
# d_loss: 0.7414
# g_loss: -0.0566
# ae_loss: 0.0859
# ae_loss1: 0.0410
# ae_loss2: 0.0450
# cls_loss: 0.1709
# Saved state dicts!
# @iter: 7300: 1.1027 it/s
# d_loss: 0.7379
# g_loss: -0.0449
# ae_loss: 0.0858
# ae_loss1: 0.0410
# ae_loss2: 0.0447
# cls_loss: 0.1727
# Saved state dicts!
# @iter: 7400: 1.1047 it/s
# d_loss: 0.7372
# g_loss: -0.0547
# ae_loss: 0.0847
# ae_loss1: 0.0404
# ae_loss2: 0.0442
# cls_loss: 0.1508
# Saved state dicts!
# test acc on clean examples (%): 88.48
# test acc on FGSM examples (%):  87.70
# test acc on BIM examples (%):   85.94
# test acc on EoT examples (%):   85.35
# test acc on BPDA examples (%):  84.57
# ________epoch 12________
# Saved state dicts!
# @iter: 7500: 0.4166 it/s
# d_loss: 0.7315
# g_loss: -0.0493
# ae_loss: 0.0853
# ae_loss1: 0.0407
# ae_loss2: 0.0445
# cls_loss: 0.1547
# Saved state dicts!
# @iter: 7600: 1.0808 it/s
# d_loss: 0.7330
# g_loss: -0.0468
# ae_loss: 0.0853
# ae_loss1: 0.0407
# ae_loss2: 0.0446
# cls_loss: 0.1956
# Saved state dicts!
# @iter: 7700: 1.1074 it/s
# d_loss: 0.7354
# g_loss: -0.0464
# ae_loss: 0.0849
# ae_loss1: 0.0406
# ae_loss2: 0.0443
# cls_loss: 0.1846
# Saved state dicts!
# @iter: 7800: 1.1012 it/s
# d_loss: 0.7343
# g_loss: -0.0575
# ae_loss: 0.0848
# ae_loss1: 0.0406
# ae_loss2: 0.0442
# cls_loss: 0.1777
# Saved state dicts!
# @iter: 7900: 1.1088 it/s
# d_loss: 0.7261
# g_loss: -0.0538
# ae_loss: 0.0847
# ae_loss1: 0.0405
# ae_loss2: 0.0442
# cls_loss: 0.1287
# Saved state dicts!
# @iter: 8000: 1.1109 it/s
# d_loss: 0.7285
# g_loss: -0.0560
# ae_loss: 0.0845
# ae_loss1: 0.0403
# ae_loss2: 0.0442
# cls_loss: 0.1542
# Saved state dicts!
# @iter: 8100: 1.0855 it/s
# d_loss: 0.7336
# g_loss: -0.0653
# ae_loss: 0.0842
# ae_loss1: 0.0405
# ae_loss2: 0.0437
# cls_loss: 0.1427
# Saved state dicts!
# test acc on clean examples (%): 84.38
# test acc on FGSM examples (%):  84.57
# test acc on BIM examples (%):   82.03
# test acc on EoT examples (%):   81.25
# test acc on BPDA examples (%):  80.47
# ________epoch 13________
# Saved state dicts!
# @iter: 8200: 0.4173 it/s
# d_loss: 0.7237
# g_loss: -0.0597
# ae_loss: 0.0832
# ae_loss1: 0.0399
# ae_loss2: 0.0433
# cls_loss: 0.1481
# Saved state dicts!
# @iter: 8300: 1.1062 it/s
# d_loss: 0.7201
# g_loss: -0.0565
# ae_loss: 0.0856
# ae_loss1: 0.0409
# ae_loss2: 0.0447
# cls_loss: 0.1966
# Saved state dicts!
# @iter: 8400: 1.1078 it/s
# d_loss: 0.7271
# g_loss: -0.0675
# ae_loss: 0.0841
# ae_loss1: 0.0401
# ae_loss2: 0.0440
# cls_loss: 0.1423
# Saved state dicts!
# @iter: 8500: 1.1044 it/s
# d_loss: 0.7375
# g_loss: -0.0750
# ae_loss: 0.0847
# ae_loss1: 0.0406
# ae_loss2: 0.0441
# cls_loss: 0.1585
# Saved state dicts!
# @iter: 8600: 1.0776 it/s
# d_loss: 0.7203
# g_loss: -0.0656
# ae_loss: 0.0851
# ae_loss1: 0.0409
# ae_loss2: 0.0442
# cls_loss: 0.1457
# Saved state dicts!
# @iter: 8700: 1.1078 it/s
# d_loss: 0.7312
# g_loss: -0.0758
# ae_loss: 0.0853
# ae_loss1: 0.0409
# ae_loss2: 0.0444
# cls_loss: 0.1580
# Saved state dicts!
# test acc on clean examples (%): 88.09
# test acc on FGSM examples (%):  88.09
# test acc on BIM examples (%):   86.13
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  84.38
# ________epoch 14________
# Saved state dicts!
# @iter: 8800: 0.4158 it/s
# d_loss: 0.7360
# g_loss: -0.0826
# ae_loss: 0.0839
# ae_loss1: 0.0401
# ae_loss2: 0.0438
# cls_loss: 0.1429
# Saved state dicts!
# @iter: 8900: 1.1045 it/s
# d_loss: 0.7329
# g_loss: -0.0802
# ae_loss: 0.0845
# ae_loss1: 0.0404
# ae_loss2: 0.0441
# cls_loss: 0.1639
# Saved state dicts!
# @iter: 9000: 1.1012 it/s
# d_loss: 0.7325
# g_loss: -0.0821
# ae_loss: 0.0843
# ae_loss1: 0.0404
# ae_loss2: 0.0439
# cls_loss: 0.1214
# Saved state dicts!
# @iter: 9100: 1.0845 it/s
# d_loss: 0.7300
# g_loss: -0.0813
# ae_loss: 0.0852
# ae_loss1: 0.0408
# ae_loss2: 0.0443
# cls_loss: 0.1585
# Saved state dicts!
# @iter: 9200: 1.1117 it/s
# d_loss: 0.7295
# g_loss: -0.0837
# ae_loss: 0.0846
# ae_loss1: 0.0404
# ae_loss2: 0.0441
# cls_loss: 0.1484
# Saved state dicts!
# @iter: 9300: 1.1051 it/s
# d_loss: 0.7356
# g_loss: -0.0967
# ae_loss: 0.0830
# ae_loss1: 0.0400
# ae_loss2: 0.0430
# cls_loss: 0.1406
# Saved state dicts!
# test acc on clean examples (%): 87.70
# test acc on FGSM examples (%):  89.06
# test acc on BIM examples (%):   85.35
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  84.57
# ________epoch 15________
# Saved state dicts!
# @iter: 9400: 0.4185 it/s
# d_loss: 0.7354
# g_loss: -0.0871
# ae_loss: 0.0851
# ae_loss1: 0.0407
# ae_loss2: 0.0444
# cls_loss: 0.1945
# Saved state dicts!
# @iter: 9500: 1.1152 it/s
# d_loss: 0.7437
# g_loss: -0.1095
# ae_loss: 0.0851
# ae_loss1: 0.0406
# ae_loss2: 0.0444
# cls_loss: 0.1691
# Saved state dicts!
# @iter: 9600: 1.0838 it/s
# d_loss: 0.7323
# g_loss: -0.0935
# ae_loss: 0.0844
# ae_loss1: 0.0404
# ae_loss2: 0.0440
# cls_loss: 0.1656
# Saved state dicts!
# @iter: 9700: 1.1109 it/s
# d_loss: 0.7250
# g_loss: -0.0958
# ae_loss: 0.0843
# ae_loss1: 0.0402
# ae_loss2: 0.0441
# cls_loss: 0.1736
# Saved state dicts!
# @iter: 9800: 1.1064 it/s
# d_loss: 0.7348
# g_loss: -0.1017
# ae_loss: 0.0834
# ae_loss1: 0.0397
# ae_loss2: 0.0437
# cls_loss: 0.1450
# Saved state dicts!
# @iter: 9900: 1.1118 it/s
# d_loss: 0.7301
# g_loss: -0.1088
# ae_loss: 0.0834
# ae_loss1: 0.0398
# ae_loss2: 0.0435
# cls_loss: 0.1554
# Saved state dicts!
# test acc on clean examples (%): 88.67
# test acc on FGSM examples (%):  89.84
# test acc on BIM examples (%):   86.91
# test acc on EoT examples (%):   86.72
# test acc on BPDA examples (%):  85.16
# ________epoch 16________
# Saved state dicts!
# @iter: 10000: 0.4184 it/s
# d_loss: 0.7313
# g_loss: -0.1083
# ae_loss: 0.0843
# ae_loss1: 0.0403
# ae_loss2: 0.0441
# cls_loss: 0.1537
# Saved state dicts!
# Saved state dicts!
# @iter: 10100: 1.0838 it/s
# d_loss: 0.7222
# g_loss: -0.1015
# ae_loss: 0.0828
# ae_loss1: 0.0397
# ae_loss2: 0.0431
# cls_loss: 0.1118
# Saved state dicts!
# @iter: 10200: 1.1159 it/s
# d_loss: 0.7234
# g_loss: -0.1016
# ae_loss: 0.0846
# ae_loss1: 0.0405
# ae_loss2: 0.0441
# cls_loss: 0.1221
# Saved state dicts!
# @iter: 10300: 1.1133 it/s
# d_loss: 0.7227
# g_loss: -0.1056
# ae_loss: 0.0836
# ae_loss1: 0.0400
# ae_loss2: 0.0435
# cls_loss: 0.1812
# Saved state dicts!
# @iter: 10400: 1.1110 it/s
# d_loss: 0.7188
# g_loss: -0.1016
# ae_loss: 0.0833
# ae_loss1: 0.0400
# ae_loss2: 0.0434
# cls_loss: 0.1397
# Saved state dicts!
# @iter: 10500: 1.1153 it/s
# d_loss: 0.7169
# g_loss: -0.1054
# ae_loss: 0.0829
# ae_loss1: 0.0396
# ae_loss2: 0.0433
# cls_loss: 0.1646
# Saved state dicts!
# @iter: 10600: 1.0883 it/s
# d_loss: 0.7225
# g_loss: -0.1030
# ae_loss: 0.0838
# ae_loss1: 0.0401
# ae_loss2: 0.0437
# cls_loss: 0.1492
# Saved state dicts!
# test acc on clean examples (%): 89.06
# test acc on FGSM examples (%):  89.84
# test acc on BIM examples (%):   86.72
# test acc on EoT examples (%):   86.72
# test acc on BPDA examples (%):  85.35
# ________epoch 17________
# Saved state dicts!
# @iter: 10700: 0.4162 it/s
# d_loss: 0.7193
# g_loss: -0.1054
# ae_loss: 0.0830
# ae_loss1: 0.0395
# ae_loss2: 0.0434
# cls_loss: 0.1199
# Saved state dicts!
# @iter: 10800: 1.1090 it/s
# d_loss: 0.7108
# g_loss: -0.0963
# ae_loss: 0.0841
# ae_loss1: 0.0403
# ae_loss2: 0.0438
# cls_loss: 0.1504
# Saved state dicts!
# @iter: 10900: 1.1115 it/s
# d_loss: 0.7154
# g_loss: -0.1034
# ae_loss: 0.0833
# ae_loss1: 0.0397
# ae_loss2: 0.0436
# cls_loss: 0.1870
# Saved state dicts!
# @iter: 11000: 1.1131 it/s
# d_loss: 0.7090
# g_loss: -0.1013
# ae_loss: 0.0840
# ae_loss1: 0.0401
# ae_loss2: 0.0439
# cls_loss: 0.1395
# Saved state dicts!
# @iter: 11100: 1.0845 it/s
# d_loss: 0.7160
# g_loss: -0.1131
# ae_loss: 0.0827
# ae_loss1: 0.0396
# ae_loss2: 0.0431
# cls_loss: 0.1115
# Saved state dicts!
# @iter: 11200: 1.1159 it/s
# d_loss: 0.7272
# g_loss: -0.1272
# ae_loss: 0.0835
# ae_loss1: 0.0400
# ae_loss2: 0.0435
# cls_loss: 0.1420
# Saved state dicts!
# test acc on clean examples (%): 87.11
# test acc on FGSM examples (%):  86.72
# test acc on BIM examples (%):   84.18
# test acc on EoT examples (%):   83.01
# test acc on BPDA examples (%):  82.81
# ________epoch 18________
# Saved state dicts!
# @iter: 11300: 0.4179 it/s
# d_loss: 0.7233
# g_loss: -0.1195
# ae_loss: 0.0820
# ae_loss1: 0.0390
# ae_loss2: 0.0430
# cls_loss: 0.1368
# Saved state dicts!
# @iter: 11400: 1.1144 it/s
# d_loss: 0.7033
# g_loss: -0.1000
# ae_loss: 0.0836
# ae_loss1: 0.0399
# ae_loss2: 0.0437
# cls_loss: 0.1636
# Saved state dicts!
# @iter: 11500: 1.1123 it/s
# d_loss: 0.7148
# g_loss: -0.1176
# ae_loss: 0.0832
# ae_loss1: 0.0397
# ae_loss2: 0.0435
# cls_loss: 0.1674
# Saved state dicts!
# @iter: 11600: 1.0856 it/s
# d_loss: 0.7165
# g_loss: -0.1099
# ae_loss: 0.0847
# ae_loss1: 0.0406
# ae_loss2: 0.0441
# cls_loss: 0.1643
# Saved state dicts!
# @iter: 11700: 1.1129 it/s
# d_loss: 0.7143
# g_loss: -0.1194
# ae_loss: 0.0824
# ae_loss1: 0.0393
# ae_loss2: 0.0431
# cls_loss: 0.1290
# Saved state dicts!
# @iter: 11800: 1.1094 it/s
# d_loss: 0.7196
# g_loss: -0.1195
# ae_loss: 0.0838
# ae_loss1: 0.0400
# ae_loss2: 0.0438
# cls_loss: 0.1354
# Saved state dicts!
# test acc on clean examples (%): 87.70
# test acc on FGSM examples (%):  86.52
# test acc on BIM examples (%):   85.16
# test acc on EoT examples (%):   84.57
# test acc on BPDA examples (%):  84.18
# ________epoch 19________
# Saved state dicts!
# @iter: 11900: 0.4210 it/s
# d_loss: 0.7177
# g_loss: -0.1203
# ae_loss: 0.0830
# ae_loss1: 0.0397
# ae_loss2: 0.0433
# cls_loss: 0.1365
# Saved state dicts!
# @iter: 12000: 1.1105 it/s
# d_loss: 0.7133
# g_loss: -0.1207
# ae_loss: 0.0826
# ae_loss1: 0.0397
# ae_loss2: 0.0430
# cls_loss: 0.1384
# Saved state dicts!
# @iter: 12100: 1.0852 it/s
# d_loss: 0.7140
# g_loss: -0.1123
# ae_loss: 0.0834
# ae_loss1: 0.0397
# ae_loss2: 0.0437
# cls_loss: 0.1398
# Saved state dicts!
# @iter: 12200: 1.1153 it/s
# d_loss: 0.7096
# g_loss: -0.1102
# ae_loss: 0.0831
# ae_loss1: 0.0397
# ae_loss2: 0.0434
# cls_loss: 0.1420
# Saved state dicts!
# @iter: 12300: 1.0946 it/s
# d_loss: 0.7218
# g_loss: -0.1207
# ae_loss: 0.0830
# ae_loss1: 0.0397
# ae_loss2: 0.0433
# cls_loss: 0.1275
# Saved state dicts!
# @iter: 12400: 1.1109 it/s
# d_loss: 0.7244
# g_loss: -0.1358
# ae_loss: 0.0827
# ae_loss1: 0.0396
# ae_loss2: 0.0431
# cls_loss: 0.1406
# Saved state dicts!
# test acc on clean examples (%): 88.09
# test acc on FGSM examples (%):  88.48
# test acc on BIM examples (%):   85.16
# test acc on EoT examples (%):   84.18
# test acc on BPDA examples (%):  84.57
# ________epoch 20________
# Saved state dicts!
# @iter: 12500: 0.4193 it/s
# d_loss: 0.7200
# g_loss: -0.1299
# ae_loss: 0.0820
# ae_loss1: 0.0393
# ae_loss2: 0.0427
# cls_loss: 0.1180
# Saved state dicts!
# @iter: 12600: 1.0838 it/s
# d_loss: 0.7235
# g_loss: -0.1351
# ae_loss: 0.0817
# ae_loss1: 0.0391
# ae_loss2: 0.0426
# cls_loss: 0.1372
# Saved state dicts!
# @iter: 12700: 1.1135 it/s
# d_loss: 0.7164
# g_loss: -0.1253
# ae_loss: 0.0829
# ae_loss1: 0.0396
# ae_loss2: 0.0433
# cls_loss: 0.1232
# Saved state dicts!
# @iter: 12800: 1.1091 it/s
# d_loss: 0.7307
# g_loss: -0.1419
# ae_loss: 0.0812
# ae_loss1: 0.0389
# ae_loss2: 0.0422
# cls_loss: 0.1142
# Saved state dicts!
# @iter: 12900: 1.1147 it/s
# d_loss: 0.7239
# g_loss: -0.1393
# ae_loss: 0.0827
# ae_loss1: 0.0396
# ae_loss2: 0.0430
# cls_loss: 0.1547
# Saved state dicts!
# @iter: 13000: 1.1174 it/s
# d_loss: 0.7261
# g_loss: -0.1391
# ae_loss: 0.0826
# ae_loss1: 0.0396
# ae_loss2: 0.0431
# cls_loss: 0.1119
# Saved state dicts!
# @iter: 13100: 1.0875 it/s
# d_loss: 0.7155
# g_loss: -0.1273
# ae_loss: 0.0823
# ae_loss1: 0.0392
# ae_loss2: 0.0431
# cls_loss: 0.1366
# Saved state dicts!
# test acc on clean examples (%): 89.26
# test acc on FGSM examples (%):  88.87
# test acc on BIM examples (%):   86.52
# test acc on EoT examples (%):   87.11
# test acc on BPDA examples (%):  87.11
# ________epoch 21________
# Saved state dicts!
# @iter: 13200: 0.4185 it/s
# d_loss: 0.7163
# g_loss: -0.1160
# ae_loss: 0.0837
# ae_loss1: 0.0400
# ae_loss2: 0.0437
# cls_loss: 0.1426
# Saved state dicts!
# @iter: 13300: 1.1146 it/s
# d_loss: 0.7180
# g_loss: -0.1328
# ae_loss: 0.0819
# ae_loss1: 0.0392
# ae_loss2: 0.0427
# cls_loss: 0.1534
# Saved state dicts!
# @iter: 13400: 1.1135 it/s
# d_loss: 0.7281
# g_loss: -0.1348
# ae_loss: 0.0826
# ae_loss1: 0.0395
# ae_loss2: 0.0431
# cls_loss: 0.1332
# Saved state dicts!
# @iter: 13500: 1.1079 it/s
# d_loss: 0.7323
# g_loss: -0.1519
# ae_loss: 0.0821
# ae_loss1: 0.0394
# ae_loss2: 0.0427
# cls_loss: 0.1380
# Saved state dicts!
# @iter: 13600: 1.0877 it/s
# d_loss: 0.7327
# g_loss: -0.1486
# ae_loss: 0.0823
# ae_loss1: 0.0392
# ae_loss2: 0.0431
# cls_loss: 0.1359
# Saved state dicts!
# @iter: 13700: 1.1127 it/s
# d_loss: 0.7236
# g_loss: -0.1461
# ae_loss: 0.0829
# ae_loss1: 0.0396
# ae_loss2: 0.0433
# cls_loss: 0.1779
# Saved state dicts!
# test acc on clean examples (%): 89.06
# test acc on FGSM examples (%):  90.04
# test acc on BIM examples (%):   86.91
# test acc on EoT examples (%):   86.52
# test acc on BPDA examples (%):  86.52
# ________epoch 22________
# Saved state dicts!
# @iter: 13800: 0.4139 it/s
# d_loss: 0.7203
# g_loss: -0.1326
# ae_loss: 0.0828
# ae_loss1: 0.0395
# ae_loss2: 0.0434
# cls_loss: 0.1331
# Saved state dicts!
# @iter: 13900: 1.1134 it/s
# d_loss: 0.7109
# g_loss: -0.1235
# ae_loss: 0.0821
# ae_loss1: 0.0392
# ae_loss2: 0.0428
# cls_loss: 0.1161
# Saved state dicts!
# @iter: 14000: 1.1136 it/s
# d_loss: 0.7183
# g_loss: -0.1298
# ae_loss: 0.0820
# ae_loss1: 0.0392
# ae_loss2: 0.0428
# cls_loss: 0.1493
# Saved state dicts!
# @iter: 14100: 1.0820 it/s
# d_loss: 0.7098
# g_loss: -0.1276
# ae_loss: 0.0839
# ae_loss1: 0.0400
# ae_loss2: 0.0438
# cls_loss: 0.1704
# Saved state dicts!
# @iter: 14200: 1.1057 it/s
# d_loss: 0.7117
# g_loss: -0.1305
# ae_loss: 0.0806
# ae_loss1: 0.0386
# ae_loss2: 0.0420
# cls_loss: 0.1269
# Saved state dicts!
# @iter: 14300: 1.1121 it/s
# d_loss: 0.7108
# g_loss: -0.1243
# ae_loss: 0.0835
# ae_loss1: 0.0396
# ae_loss2: 0.0439
# cls_loss: 0.1368
# Saved state dicts!
# test acc on clean examples (%): 88.28
# test acc on FGSM examples (%):  88.48
# test acc on BIM examples (%):   86.72
# test acc on EoT examples (%):   85.94
# test acc on BPDA examples (%):  84.96
# ________epoch 23________
# Saved state dicts!
# @iter: 14400: 0.4184 it/s
# d_loss: 0.7233
# g_loss: -0.1360
# ae_loss: 0.0841
# ae_loss1: 0.0402
# ae_loss2: 0.0439
# cls_loss: 0.1506
# Saved state dicts!
# @iter: 14500: 1.1051 it/s
# d_loss: 0.7095
# g_loss: -0.1237
# ae_loss: 0.0838
# ae_loss1: 0.0401
# ae_loss2: 0.0437
# cls_loss: 0.1601
# Saved state dicts!
# @iter: 14600: 1.0720 it/s
# d_loss: 0.7169
# g_loss: -0.1332
# ae_loss: 0.0832
# ae_loss1: 0.0400
# ae_loss2: 0.0433
# cls_loss: 0.1428
# Saved state dicts!
# @iter: 14700: 1.0982 it/s
# d_loss: 0.7187
# g_loss: -0.1382
# ae_loss: 0.0816
# ae_loss1: 0.0390
# ae_loss2: 0.0426
# cls_loss: 0.1183
# Saved state dicts!
# @iter: 14800: 1.1111 it/s
# d_loss: 0.7221
# g_loss: -0.1391
# ae_loss: 0.0825
# ae_loss1: 0.0395
# ae_loss2: 0.0430
# cls_loss: 0.1317
# Saved state dicts!
# @iter: 14900: 1.1017 it/s
# d_loss: 0.7193
# g_loss: -0.1360
# ae_loss: 0.0821
# ae_loss1: 0.0393
# ae_loss2: 0.0428
# cls_loss: 0.1443
# Saved state dicts!
# test acc on clean examples (%): 88.28
# test acc on FGSM examples (%):  88.28
# test acc on BIM examples (%):   86.52
# test acc on EoT examples (%):   85.35
# test acc on BPDA examples (%):  84.77
# ________epoch 24________
# Saved state dicts!
# @iter: 15000: 0.4142 it/s
# d_loss: 0.7223
# g_loss: -0.1446
# ae_loss: 0.0813
# ae_loss1: 0.0389
# ae_loss2: 0.0424
# cls_loss: 0.1093
# Saved state dicts!
# Saved state dicts!
# @iter: 15100: 1.0682 it/s
# d_loss: 0.7197
# g_loss: -0.1380
# ae_loss: 0.0827
# ae_loss1: 0.0395
# ae_loss2: 0.0432
# cls_loss: 0.1652
# Saved state dicts!
# @iter: 15200: 1.1115 it/s
# d_loss: 0.7217
# g_loss: -0.1466
# ae_loss: 0.0824
# ae_loss1: 0.0393
# ae_loss2: 0.0432
# cls_loss: 0.1394
# Saved state dicts!
# @iter: 15300: 1.1028 it/s
# d_loss: 0.7256
# g_loss: -0.1472
# ae_loss: 0.0839
# ae_loss1: 0.0400
# ae_loss2: 0.0439
# cls_loss: 0.1334
# Saved state dicts!
# @iter: 15400: 1.1027 it/s
# d_loss: 0.7259
# g_loss: -0.1562
# ae_loss: 0.0827
# ae_loss1: 0.0396
# ae_loss2: 0.0431
# cls_loss: 0.1450
# Saved state dicts!
# @iter: 15500: 1.1107 it/s
# d_loss: 0.7329
# g_loss: -0.1628
# ae_loss: 0.0813
# ae_loss1: 0.0390
# ae_loss2: 0.0422
# cls_loss: 0.1146
# Saved state dicts!
# @iter: 15600: 1.0903 it/s
# d_loss: 0.7284
# g_loss: -0.1549
# ae_loss: 0.0810
# ae_loss1: 0.0390
# ae_loss2: 0.0421
# cls_loss: 0.1018
# Saved state dicts!
# test acc on clean examples (%): 86.33
# test acc on FGSM examples (%):  87.11
# test acc on BIM examples (%):   84.57
# test acc on EoT examples (%):   83.79
# test acc on BPDA examples (%):  83.79
# ________epoch 25________
# Saved state dicts!
# @iter: 15700: 0.4194 it/s
# d_loss: 0.7368
# g_loss: -0.1569
# ae_loss: 0.0817
# ae_loss1: 0.0392
# ae_loss2: 0.0425
# cls_loss: 0.1296
# Saved state dicts!
# @iter: 15800: 1.1112 it/s
# d_loss: 0.7328
# g_loss: -0.1556
# ae_loss: 0.0831
# ae_loss1: 0.0398
# ae_loss2: 0.0433
# cls_loss: 0.1579
# Saved state dicts!
# @iter: 15900: 1.1031 it/s
# d_loss: 0.7263
# g_loss: -0.1421
# ae_loss: 0.0827
# ae_loss1: 0.0395
# ae_loss2: 0.0432
# cls_loss: 0.1383
# Saved state dicts!
# @iter: 16000: 1.1013 it/s
# d_loss: 0.7222
# g_loss: -0.1374
# ae_loss: 0.0835
# ae_loss1: 0.0398
# ae_loss2: 0.0437
# cls_loss: 0.1482
# Saved state dicts!
# @iter: 16100: 1.0867 it/s
# d_loss: 0.7265
# g_loss: -0.1535
# ae_loss: 0.0831
# ae_loss1: 0.0397
# ae_loss2: 0.0434
# cls_loss: 0.1235
# Saved state dicts!
# @iter: 16200: 1.1132 it/s
# d_loss: 0.7271
# g_loss: -0.1538
# ae_loss: 0.0810
# ae_loss1: 0.0386
# ae_loss2: 0.0424
# cls_loss: 0.1137
# Saved state dicts!
# test acc on clean examples (%): 91.02
# test acc on FGSM examples (%):  91.99
# test acc on BIM examples (%):   89.06
# test acc on EoT examples (%):   89.06
# test acc on BPDA examples (%):  88.48
# ________epoch 26________
# Saved state dicts!
# @iter: 16300: 0.4180 it/s
# d_loss: 0.7207
# g_loss: -0.1384
# ae_loss: 0.0820
# ae_loss1: 0.0392
# ae_loss2: 0.0428
# cls_loss: 0.1215
# Saved state dicts!
# @iter: 16400: 1.0995 it/s
# d_loss: 0.7160
# g_loss: -0.1409
# ae_loss: 0.0823
# ae_loss1: 0.0394
# ae_loss2: 0.0429
# cls_loss: 0.1169
# Saved state dicts!
# @iter: 16500: 1.1050 it/s
# d_loss: 0.7317
# g_loss: -0.1548
# ae_loss: 0.0808
# ae_loss1: 0.0388
# ae_loss2: 0.0420
# cls_loss: 0.1005
# Saved state dicts!
# @iter: 16600: 1.0751 it/s
# d_loss: 0.7291
# g_loss: -0.1530
# ae_loss: 0.0826
# ae_loss1: 0.0394
# ae_loss2: 0.0432
# cls_loss: 0.1500
# Saved state dicts!
# @iter: 16700: 1.1098 it/s
# d_loss: 0.7232
# g_loss: -0.1480
# ae_loss: 0.0817
# ae_loss1: 0.0391
# ae_loss2: 0.0426
# cls_loss: 0.1424
# Saved state dicts!
# @iter: 16800: 1.1039 it/s
# d_loss: 0.7251
# g_loss: -0.1508
# ae_loss: 0.0819
# ae_loss1: 0.0391
# ae_loss2: 0.0428
# cls_loss: 0.1370
# Saved state dicts!
# test acc on clean examples (%): 88.09
# test acc on FGSM examples (%):  90.04
# test acc on BIM examples (%):   85.55
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  86.13
# ________epoch 27________
# Saved state dicts!
# @iter: 16900: 0.4167 it/s
# d_loss: 0.7243
# g_loss: -0.1473
# ae_loss: 0.0819
# ae_loss1: 0.0392
# ae_loss2: 0.0427
# cls_loss: 0.1146
# Saved state dicts!
# @iter: 17000: 1.1110 it/s
# d_loss: 0.7246
# g_loss: -0.1478
# ae_loss: 0.0823
# ae_loss1: 0.0394
# ae_loss2: 0.0429
# cls_loss: 0.1494
# Saved state dicts!
# @iter: 17100: 1.0749 it/s
# d_loss: 0.7242
# g_loss: -0.1497
# ae_loss: 0.0816
# ae_loss1: 0.0390
# ae_loss2: 0.0426
# cls_loss: 0.1208
# Saved state dicts!
# @iter: 17200: 1.1104 it/s
# d_loss: 0.7234
# g_loss: -0.1537
# ae_loss: 0.0819
# ae_loss1: 0.0392
# ae_loss2: 0.0427
# cls_loss: 0.1434
# Saved state dicts!
# @iter: 17300: 1.1031 it/s
# d_loss: 0.7253
# g_loss: -0.1490
# ae_loss: 0.0809
# ae_loss1: 0.0387
# ae_loss2: 0.0422
# cls_loss: 0.1219
# Saved state dicts!
# @iter: 17400: 1.1048 it/s
# d_loss: 0.7282
# g_loss: -0.1545
# ae_loss: 0.0812
# ae_loss1: 0.0387
# ae_loss2: 0.0425
# cls_loss: 0.1191
# Saved state dicts!
# test acc on clean examples (%): 87.50
# test acc on FGSM examples (%):  89.65
# test acc on BIM examples (%):   84.96
# test acc on EoT examples (%):   84.57
# test acc on BPDA examples (%):  84.38
# ________epoch 28________
# Saved state dicts!
# @iter: 17500: 0.4137 it/s
# d_loss: 0.7272
# g_loss: -0.1451
# ae_loss: 0.0826
# ae_loss1: 0.0394
# ae_loss2: 0.0432
# cls_loss: 0.1415
# Saved state dicts!
# @iter: 17600: 1.0754 it/s
# d_loss: 0.7394
# g_loss: -0.1627
# ae_loss: 0.0804
# ae_loss1: 0.0384
# ae_loss2: 0.0420
# cls_loss: 0.1187
# Saved state dicts!
# @iter: 17700: 1.1066 it/s
# d_loss: 0.7125
# g_loss: -0.1371
# ae_loss: 0.0823
# ae_loss1: 0.0394
# ae_loss2: 0.0429
# cls_loss: 0.1040
# Saved state dicts!
# @iter: 17800: 1.1184 it/s
# d_loss: 0.7199
# g_loss: -0.1514
# ae_loss: 0.0826
# ae_loss1: 0.0395
# ae_loss2: 0.0431
# cls_loss: 0.1123
# Saved state dicts!
# @iter: 17900: 1.1128 it/s
# d_loss: 0.7241
# g_loss: -0.1481
# ae_loss: 0.0827
# ae_loss1: 0.0394
# ae_loss2: 0.0433
# cls_loss: 0.1411
# Saved state dicts!
# @iter: 18000: 1.1163 it/s
# d_loss: 0.7323
# g_loss: -0.1609
# ae_loss: 0.0806
# ae_loss1: 0.0386
# ae_loss2: 0.0420
# cls_loss: 0.0872
# Saved state dicts!
# @iter: 18100: 1.0883 it/s
# d_loss: 0.7321
# g_loss: -0.1585
# ae_loss: 0.0822
# ae_loss1: 0.0394
# ae_loss2: 0.0428
# cls_loss: 0.1585
# Saved state dicts!
# test acc on clean examples (%): 91.02
# test acc on FGSM examples (%):  92.19
# test acc on BIM examples (%):   89.45
# test acc on EoT examples (%):   88.87
# test acc on BPDA examples (%):  88.28
# ________epoch 29________
# Saved state dicts!
# @iter: 18200: 0.4173 it/s
# d_loss: 0.7379
# g_loss: -0.1723
# ae_loss: 0.0823
# ae_loss1: 0.0393
# ae_loss2: 0.0430
# cls_loss: 0.1095
# Saved state dicts!
# @iter: 18300: 1.1097 it/s
# d_loss: 0.7352
# g_loss: -0.1629
# ae_loss: 0.0822
# ae_loss1: 0.0395
# ae_loss2: 0.0428
# cls_loss: 0.1225
# Saved state dicts!
# @iter: 18400: 1.1087 it/s
# d_loss: 0.7290
# g_loss: -0.1617
# ae_loss: 0.0820
# ae_loss1: 0.0393
# ae_loss2: 0.0428
# cls_loss: 0.1369
# Saved state dicts!
# @iter: 18500: 1.0989 it/s
# d_loss: 0.7280
# g_loss: -0.1535
# ae_loss: 0.0809
# ae_loss1: 0.0387
# ae_loss2: 0.0422
# cls_loss: 0.1229
# Saved state dicts!
# @iter: 18600: 1.0881 it/s
# d_loss: 0.7248
# g_loss: -0.1630
# ae_loss: 0.0808
# ae_loss1: 0.0388
# ae_loss2: 0.0420
# cls_loss: 0.1077
# Saved state dicts!
# @iter: 18700: 1.1105 it/s
# d_loss: 0.7295
# g_loss: -0.1670
# ae_loss: 0.0819
# ae_loss1: 0.0393
# ae_loss2: 0.0427
# cls_loss: 0.1162
# Saved state dicts!
# test acc on clean examples (%): 89.45
# test acc on FGSM examples (%):  89.84
# test acc on BIM examples (%):   86.91
# test acc on EoT examples (%):   86.33
# test acc on BPDA examples (%):  85.74
# ________epoch 30________
# Saved state dicts!
# @iter: 18800: 0.4170 it/s
# d_loss: 0.7346
# g_loss: -0.1662
# ae_loss: 0.0807
# ae_loss1: 0.0386
# ae_loss2: 0.0421
# cls_loss: 0.1348
# Saved state dicts!
# @iter: 18900: 1.1134 it/s
# d_loss: 0.7337
# g_loss: -0.1665
# ae_loss: 0.0804
# ae_loss1: 0.0385
# ae_loss2: 0.0419
# cls_loss: 0.1036
# Saved state dicts!
# @iter: 19000: 1.1133 it/s
# d_loss: 0.7341
# g_loss: -0.1657
# ae_loss: 0.0819
# ae_loss1: 0.0392
# ae_loss2: 0.0427
# cls_loss: 0.1233
# Saved state dicts!
# @iter: 19100: 1.0899 it/s
# d_loss: 0.7310
# g_loss: -0.1593
# ae_loss: 0.0808
# ae_loss1: 0.0386
# ae_loss2: 0.0421
# cls_loss: 0.1635
# Saved state dicts!
# @iter: 19200: 1.1125 it/s
# d_loss: 0.7336
# g_loss: -0.1657
# ae_loss: 0.0825
# ae_loss1: 0.0394
# ae_loss2: 0.0432
# cls_loss: 0.1558
# Saved state dicts!
# @iter: 19300: 1.1185 it/s
# d_loss: 0.7356
# g_loss: -0.1647
# ae_loss: 0.0832
# ae_loss1: 0.0398
# ae_loss2: 0.0434
# cls_loss: 0.1238
# Saved state dicts!
# test acc on clean examples (%): 90.62
# test acc on FGSM examples (%):  91.02
# test acc on BIM examples (%):   88.28
# test acc on EoT examples (%):   87.50
# test acc on BPDA examples (%):  88.28
# ________epoch 31________
# Saved state dicts!
# @iter: 19400: 0.4190 it/s
# d_loss: 0.7436
# g_loss: -0.1760
# ae_loss: 0.0831
# ae_loss1: 0.0398
# ae_loss2: 0.0433
# cls_loss: 0.1463
# Saved state dicts!
# @iter: 19500: 1.1102 it/s
# d_loss: 0.7349
# g_loss: -0.1679
# ae_loss: 0.0823
# ae_loss1: 0.0395
# ae_loss2: 0.0429
# cls_loss: 0.1469
# Saved state dicts!
# @iter: 19600: 1.0877 it/s
# d_loss: 0.7443
# g_loss: -0.1745
# ae_loss: 0.0815
# ae_loss1: 0.0391
# ae_loss2: 0.0424
# cls_loss: 0.1453
# Saved state dicts!
# @iter: 19700: 1.1141 it/s
# d_loss: 0.7373
# g_loss: -0.1664
# ae_loss: 0.0806
# ae_loss1: 0.0388
# ae_loss2: 0.0418
# cls_loss: 0.1209
# Saved state dicts!
# @iter: 19800: 1.1160 it/s
# d_loss: 0.7337
# g_loss: -0.1659
# ae_loss: 0.0817
# ae_loss1: 0.0391
# ae_loss2: 0.0426
# cls_loss: 0.1113
# Saved state dicts!
# @iter: 19900: 1.1093 it/s
# d_loss: 0.7394
# g_loss: -0.1731
# ae_loss: 0.0808
# ae_loss1: 0.0387
# ae_loss2: 0.0421
# cls_loss: 0.1361
# Saved state dicts!
# test acc on clean examples (%): 90.43
# test acc on FGSM examples (%):  90.43
# test acc on BIM examples (%):   88.28
# test acc on EoT examples (%):   87.70
# test acc on BPDA examples (%):  87.30
# ________epoch 32________
# Saved state dicts!
# @iter: 20000: 0.4186 it/s
# d_loss: 0.7377
# g_loss: -0.1723
# ae_loss: 0.0814
# ae_loss1: 0.0390
# ae_loss2: 0.0424
# cls_loss: 0.1348
# Saved state dicts!
# Saved state dicts!
# @iter: 20100: 1.0835 it/s
# d_loss: 0.7387
# g_loss: -0.1693
# ae_loss: 0.0812
# ae_loss1: 0.0389
# ae_loss2: 0.0423
# cls_loss: 0.1370
# Saved state dicts!
# @iter: 20200: 1.1121 it/s
# d_loss: 0.7379
# g_loss: -0.1636
# ae_loss: 0.0812
# ae_loss1: 0.0389
# ae_loss2: 0.0423
# cls_loss: 0.1408
# Saved state dicts!
# @iter: 20300: 1.1106 it/s
# d_loss: 0.7386
# g_loss: -0.1702
# ae_loss: 0.0806
# ae_loss1: 0.0386
# ae_loss2: 0.0421
# cls_loss: 0.1184
# Saved state dicts!
# @iter: 20400: 1.1089 it/s
# d_loss: 0.7352
# g_loss: -0.1676
# ae_loss: 0.0807
# ae_loss1: 0.0386
# ae_loss2: 0.0421
# cls_loss: 0.1024
# Saved state dicts!
# @iter: 20500: 1.1104 it/s
# d_loss: 0.7359
# g_loss: -0.1634
# ae_loss: 0.0820
# ae_loss1: 0.0392
# ae_loss2: 0.0428
# cls_loss: 0.1285
# Saved state dicts!
# @iter: 20600: 1.0855 it/s
# d_loss: 0.7350
# g_loss: -0.1633
# ae_loss: 0.0812
# ae_loss1: 0.0388
# ae_loss2: 0.0424
# cls_loss: 0.1080
# Saved state dicts!
# test acc on clean examples (%): 88.87
# test acc on FGSM examples (%):  89.45
# test acc on BIM examples (%):   87.11
# test acc on EoT examples (%):   86.52
# test acc on BPDA examples (%):  85.94
# ________epoch 33________
# Saved state dicts!
# @iter: 20700: 0.4160 it/s
# d_loss: 0.7323
# g_loss: -0.1753
# ae_loss: 0.0809
# ae_loss1: 0.0389
# ae_loss2: 0.0421
# cls_loss: 0.1510
# Saved state dicts!
# @iter: 20800: 1.1050 it/s
# d_loss: 0.7414
# g_loss: -0.1707
# ae_loss: 0.0810
# ae_loss1: 0.0388
# ae_loss2: 0.0422
# cls_loss: 0.1411
# Saved state dicts!
# @iter: 20900: 1.1120 it/s
# d_loss: 0.7255
# g_loss: -0.1548
# ae_loss: 0.0813
# ae_loss1: 0.0390
# ae_loss2: 0.0424
# cls_loss: 0.1302
# Saved state dicts!
# @iter: 21000: 1.1154 it/s
# d_loss: 0.7371
# g_loss: -0.1631
# ae_loss: 0.0817
# ae_loss1: 0.0389
# ae_loss2: 0.0428
# cls_loss: 0.1400
# Saved state dicts!
# @iter: 21100: 1.0859 it/s
# d_loss: 0.7343
# g_loss: -0.1631
# ae_loss: 0.0821
# ae_loss1: 0.0392
# ae_loss2: 0.0429
# cls_loss: 0.1413
# Saved state dicts!
# @iter: 21200: 1.1109 it/s
# d_loss: 0.7376
# g_loss: -0.1767
# ae_loss: 0.0812
# ae_loss1: 0.0389
# ae_loss2: 0.0423
# cls_loss: 0.1145
# Saved state dicts!
# test acc on clean examples (%): 89.84
# test acc on FGSM examples (%):  90.23
# test acc on BIM examples (%):   88.09
# test acc on EoT examples (%):   87.11
# test acc on BPDA examples (%):  87.89
# ________epoch 34________
# Saved state dicts!
# @iter: 21300: 0.4203 it/s
# d_loss: 0.7407
# g_loss: -0.1780
# ae_loss: 0.0803
# ae_loss1: 0.0385
# ae_loss2: 0.0418
# cls_loss: 0.1110
# Saved state dicts!
# @iter: 21400: 1.1055 it/s
# d_loss: 0.7394
# g_loss: -0.1722
# ae_loss: 0.0823
# ae_loss1: 0.0394
# ae_loss2: 0.0429
# cls_loss: 0.1093
# Saved state dicts!
# @iter: 21500: 1.1167 it/s
# d_loss: 0.7340
# g_loss: -0.1702
# ae_loss: 0.0808
# ae_loss1: 0.0388
# ae_loss2: 0.0421
# cls_loss: 0.0989
# Saved state dicts!
# @iter: 21600: 1.0875 it/s
# d_loss: 0.7334
# g_loss: -0.1698
# ae_loss: 0.0787
# ae_loss1: 0.0377
# ae_loss2: 0.0409
# cls_loss: 0.0974
# Saved state dicts!
# @iter: 21700: 1.1073 it/s
# d_loss: 0.7441
# g_loss: -0.1742
# ae_loss: 0.0800
# ae_loss1: 0.0384
# ae_loss2: 0.0416
# cls_loss: 0.1267
# Saved state dicts!
# @iter: 21800: 1.1134 it/s
# d_loss: 0.7396
# g_loss: -0.1752
# ae_loss: 0.0809
# ae_loss1: 0.0388
# ae_loss2: 0.0421
# cls_loss: 0.1281
# Saved state dicts!
# test acc on clean examples (%): 87.30
# test acc on FGSM examples (%):  88.48
# test acc on BIM examples (%):   86.13
# test acc on EoT examples (%):   85.35
# test acc on BPDA examples (%):  85.74
# ________epoch 35________
# Saved state dicts!
# @iter: 21900: 0.4144 it/s
# d_loss: 0.7248
# g_loss: -0.1643
# ae_loss: 0.0807
# ae_loss1: 0.0387
# ae_loss2: 0.0420
# cls_loss: 0.1170
# Saved state dicts!
# @iter: 22000: 1.1037 it/s
# d_loss: 0.7304
# g_loss: -0.1689
# ae_loss: 0.0804
# ae_loss1: 0.0386
# ae_loss2: 0.0418
# cls_loss: 0.1116
# Saved state dicts!
# @iter: 22100: 1.0872 it/s
# d_loss: 0.7392
# g_loss: -0.1734
# ae_loss: 0.0818
# ae_loss1: 0.0392
# ae_loss2: 0.0425
# cls_loss: 0.1331
# Saved state dicts!
# @iter: 22200: 1.1056 it/s
# d_loss: 0.7484
# g_loss: -0.1837
# ae_loss: 0.0792
# ae_loss1: 0.0381
# ae_loss2: 0.0411
# cls_loss: 0.1043
# Saved state dicts!
# @iter: 22300: 1.0918 it/s
# d_loss: 0.7409
# g_loss: -0.1821
# ae_loss: 0.0812
# ae_loss1: 0.0389
# ae_loss2: 0.0424
# cls_loss: 0.1390
# Saved state dicts!
# @iter: 22400: 1.0988 it/s
# d_loss: 0.7425
# g_loss: -0.1821
# ae_loss: 0.0817
# ae_loss1: 0.0393
# ae_loss2: 0.0424
# cls_loss: 0.1438
# Saved state dicts!
# test acc on clean examples (%): 87.89
# test acc on FGSM examples (%):  89.26
# test acc on BIM examples (%):   85.94
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  84.38
# ________epoch 36________
# Saved state dicts!
# @iter: 22500: 0.4163 it/s
# d_loss: 0.7424
# g_loss: -0.1778
# ae_loss: 0.0810
# ae_loss1: 0.0390
# ae_loss2: 0.0420
# cls_loss: 0.1012
# Saved state dicts!
# @iter: 22600: 1.0837 it/s
# d_loss: 0.7363
# g_loss: -0.1786
# ae_loss: 0.0803
# ae_loss1: 0.0385
# ae_loss2: 0.0418
# cls_loss: 0.1552
# Saved state dicts!
# @iter: 22700: 1.1158 it/s
# d_loss: 0.7468
# g_loss: -0.1870
# ae_loss: 0.0816
# ae_loss1: 0.0389
# ae_loss2: 0.0427
# cls_loss: 0.1204
# Saved state dicts!
# @iter: 22800: 1.1111 it/s
# d_loss: 0.7512
# g_loss: -0.1941
# ae_loss: 0.0820
# ae_loss1: 0.0392
# ae_loss2: 0.0427
# cls_loss: 0.1248
# Saved state dicts!
# @iter: 22900: 1.1103 it/s
# d_loss: 0.7449
# g_loss: -0.1819
# ae_loss: 0.0809
# ae_loss1: 0.0387
# ae_loss2: 0.0422
# cls_loss: 0.1446
# Saved state dicts!
# @iter: 23000: 1.1131 it/s
# d_loss: 0.7449
# g_loss: -0.1818
# ae_loss: 0.0803
# ae_loss1: 0.0387
# ae_loss2: 0.0416
# cls_loss: 0.0835
# Saved state dicts!
# @iter: 23100: 1.0860 it/s
# d_loss: 0.7390
# g_loss: -0.1761
# ae_loss: 0.0823
# ae_loss1: 0.0396
# ae_loss2: 0.0427
# cls_loss: 0.1021
# Saved state dicts!
# test acc on clean examples (%): 89.45
# test acc on FGSM examples (%):  90.04
# test acc on BIM examples (%):   87.50
# test acc on EoT examples (%):   87.50
# test acc on BPDA examples (%):  86.13
# ________epoch 37________
# Saved state dicts!
# @iter: 23200: 0.4162 it/s
# d_loss: 0.7566
# g_loss: -0.1899
# ae_loss: 0.0808
# ae_loss1: 0.0386
# ae_loss2: 0.0422
# cls_loss: 0.1218
# Saved state dicts!
# @iter: 23300: 1.1066 it/s
# d_loss: 0.7535
# g_loss: -0.1923
# ae_loss: 0.0812
# ae_loss1: 0.0391
# ae_loss2: 0.0422
# cls_loss: 0.1252
# Saved state dicts!
# @iter: 23400: 1.1073 it/s
# d_loss: 0.7404
# g_loss: -0.1788
# ae_loss: 0.0806
# ae_loss1: 0.0386
# ae_loss2: 0.0420
# cls_loss: 0.1252
# Saved state dicts!
# @iter: 23500: 1.1071 it/s
# d_loss: 0.7403
# g_loss: -0.1688
# ae_loss: 0.0817
# ae_loss1: 0.0391
# ae_loss2: 0.0425
# cls_loss: 0.1287
# Saved state dicts!
# @iter: 23600: 1.0755 it/s
# d_loss: 0.7366
# g_loss: -0.1701
# ae_loss: 0.0808
# ae_loss1: 0.0386
# ae_loss2: 0.0422
# cls_loss: 0.1141
# Saved state dicts!
# @iter: 23700: 1.1093 it/s
# d_loss: 0.7361
# g_loss: -0.1724
# ae_loss: 0.0806
# ae_loss1: 0.0386
# ae_loss2: 0.0420
# cls_loss: 0.1162
# Saved state dicts!
# test acc on clean examples (%): 87.50
# test acc on FGSM examples (%):  89.06
# test acc on BIM examples (%):   84.96
# test acc on EoT examples (%):   84.96
# test acc on BPDA examples (%):  84.18
# ________epoch 38________
# Saved state dicts!
# @iter: 23800: 0.4204 it/s
# d_loss: 0.7394
# g_loss: -0.1735
# ae_loss: 0.0814
# ae_loss1: 0.0390
# ae_loss2: 0.0424
# cls_loss: 0.1353
# Saved state dicts!
# @iter: 23900: 1.1151 it/s
# d_loss: 0.7415
# g_loss: -0.1756
# ae_loss: 0.0802
# ae_loss1: 0.0383
# ae_loss2: 0.0419
# cls_loss: 0.1643
# Saved state dicts!
# @iter: 24000: 1.1143 it/s
# d_loss: 0.7366
# g_loss: -0.1623
# ae_loss: 0.0810
# ae_loss1: 0.0389
# ae_loss2: 0.0422
# cls_loss: 0.1181
# Saved state dicts!
# @iter: 24100: 1.0807 it/s
# d_loss: 0.7322
# g_loss: -0.1720
# ae_loss: 0.0800
# ae_loss1: 0.0384
# ae_loss2: 0.0416
# cls_loss: 0.1200
# Saved state dicts!
# @iter: 24200: 1.1024 it/s
# d_loss: 0.7403
# g_loss: -0.1837
# ae_loss: 0.0810
# ae_loss1: 0.0389
# ae_loss2: 0.0421
# cls_loss: 0.0934
# Saved state dicts!
# @iter: 24300: 1.1034 it/s
# d_loss: 0.7322
# g_loss: -0.1602
# ae_loss: 0.0813
# ae_loss1: 0.0392
# ae_loss2: 0.0421
# cls_loss: 0.0942
# Saved state dicts!
# test acc on clean examples (%): 87.89
# test acc on FGSM examples (%):  89.06
# test acc on BIM examples (%):   85.55
# test acc on EoT examples (%):   85.35
# test acc on BPDA examples (%):  85.16
# ________epoch 39________
# Saved state dicts!
# @iter: 24400: 0.4096 it/s
# d_loss: 0.7404
# g_loss: -0.1754
# ae_loss: 0.0801
# ae_loss1: 0.0384
# ae_loss2: 0.0416
# cls_loss: 0.1062
# Saved state dicts!
# @iter: 24500: 1.1098 it/s
# d_loss: 0.7401
# g_loss: -0.1776
# ae_loss: 0.0824
# ae_loss1: 0.0395
# ae_loss2: 0.0429
# cls_loss: 0.1386
# Saved state dicts!
# @iter: 24600: 1.0679 it/s
# d_loss: 0.7519
# g_loss: -0.1905
# ae_loss: 0.0785
# ae_loss1: 0.0377
# ae_loss2: 0.0408
# cls_loss: 0.1054
# Saved state dicts!
# @iter: 24700: 1.0924 it/s
# d_loss: 0.7448
# g_loss: -0.1804
# ae_loss: 0.0802
# ae_loss1: 0.0384
# ae_loss2: 0.0418
# cls_loss: 0.1251
# Saved state dicts!
# @iter: 24800: 1.0861 it/s
# d_loss: 0.7437
# g_loss: -0.1732
# ae_loss: 0.0809
# ae_loss1: 0.0387
# ae_loss2: 0.0422
# cls_loss: 0.1053
# Saved state dicts!
# @iter: 24900: 1.1079 it/s
# d_loss: 0.7436
# g_loss: -0.1826
# ae_loss: 0.0804
# ae_loss1: 0.0386
# ae_loss2: 0.0419
# cls_loss: 0.1199
# Saved state dicts!
# test acc on clean examples (%): 85.94
# test acc on FGSM examples (%):  88.48
# test acc on BIM examples (%):   84.38
# test acc on EoT examples (%):   83.20
# test acc on BPDA examples (%):  83.20
# ________epoch 40________
# Saved state dicts!
# @iter: 25000: 0.4075 it/s
# d_loss: 0.7490
# g_loss: -0.1863
# ae_loss: 0.0800
# ae_loss1: 0.0383
# ae_loss2: 0.0417
# cls_loss: 0.1228
# Saved state dicts!
# Saved state dicts!
# @iter: 25100: 1.0846 it/s
# d_loss: 0.7433
# g_loss: -0.1748
# ae_loss: 0.0808
# ae_loss1: 0.0388
# ae_loss2: 0.0420
# cls_loss: 0.1302
# Saved state dicts!
# @iter: 25200: 1.1051 it/s
# d_loss: 0.7380
# g_loss: -0.1748
# ae_loss: 0.0801
# ae_loss1: 0.0385
# ae_loss2: 0.0416
# cls_loss: 0.1108
# Saved state dicts!
# @iter: 25300: 1.1078 it/s
# d_loss: 0.7422
# g_loss: -0.1794
# ae_loss: 0.0801
# ae_loss1: 0.0385
# ae_loss2: 0.0416
# cls_loss: 0.1225
# Saved state dicts!
# @iter: 25400: 1.0968 it/s
# d_loss: 0.7352
# g_loss: -0.1704
# ae_loss: 0.0819
# ae_loss1: 0.0391
# ae_loss2: 0.0429
# cls_loss: 0.1399
# Saved state dicts!
# @iter: 25500: 1.0932 it/s
# d_loss: 0.7481
# g_loss: -0.1972
# ae_loss: 0.0802
# ae_loss1: 0.0386
# ae_loss2: 0.0416
# cls_loss: 0.1142
# Saved state dicts!
# @iter: 25600: 1.0773 it/s
# d_loss: 0.7597
# g_loss: -0.1919
# ae_loss: 0.0811
# ae_loss1: 0.0387
# ae_loss2: 0.0423
# cls_loss: 0.1392
# Saved state dicts!
# test acc on clean examples (%): 88.48
# test acc on FGSM examples (%):  89.26
# test acc on BIM examples (%):   88.09
# test acc on EoT examples (%):   87.30
# test acc on BPDA examples (%):  86.33
# ________epoch 41________
# Saved state dicts!
# @iter: 25700: 0.4188 it/s
# d_loss: 0.7497
# g_loss: -0.1881
# ae_loss: 0.0813
# ae_loss1: 0.0389
# ae_loss2: 0.0424
# cls_loss: 0.1071
# Saved state dicts!
# @iter: 25800: 1.1135 it/s
# d_loss: 0.7425
# g_loss: -0.1820
# ae_loss: 0.0809
# ae_loss1: 0.0389
# ae_loss2: 0.0420
# cls_loss: 0.1207
# Saved state dicts!
# @iter: 25900: 1.1100 it/s
# d_loss: 0.7509
# g_loss: -0.1903
# ae_loss: 0.0805
# ae_loss1: 0.0388
# ae_loss2: 0.0418
# cls_loss: 0.1167
# Saved state dicts!
# @iter: 26000: 1.1083 it/s
# d_loss: 0.7419
# g_loss: -0.1758
# ae_loss: 0.0807
# ae_loss1: 0.0389
# ae_loss2: 0.0418
# cls_loss: 0.1398
# Saved state dicts!
# @iter: 26100: 1.0731 it/s
# d_loss: 0.7465
# g_loss: -0.1906
# ae_loss: 0.0816
# ae_loss1: 0.0393
# ae_loss2: 0.0423
# cls_loss: 0.1523
# Saved state dicts!
# @iter: 26200: 1.1025 it/s
# d_loss: 0.7529
# g_loss: -0.1898
# ae_loss: 0.0809
# ae_loss1: 0.0389
# ae_loss2: 0.0420
# cls_loss: 0.1015
# Saved state dicts!
# test acc on clean examples (%): 85.35
# test acc on FGSM examples (%):  86.52
# test acc on BIM examples (%):   83.79
# test acc on EoT examples (%):   83.40
# test acc on BPDA examples (%):  83.01
# ________epoch 42________
# Saved state dicts!
# @iter: 26300: 0.4167 it/s
# d_loss: 0.7431
# g_loss: -0.1955
# ae_loss: 0.0792
# ae_loss1: 0.0380
# ae_loss2: 0.0412
# cls_loss: 0.0910
# ...
# d_loss: 0.7501
# g_loss: -0.1947
# ae_loss: 0.0794
# ae_loss1: 0.0383
# ae_loss2: 0.0411
# cls_loss: 0.1087
# Saved state dicts!
# @iter: 30800: 1.0895 it/s
# d_loss: 0.7474
# g_loss: -0.1920
# ae_loss: 0.0811
# ae_loss1: 0.0390
# ae_loss2: 0.0421
# cls_loss: 0.1379
# Saved state dicts!
# @iter: 30900: 1.0919 it/s
# d_loss: 0.7528
# g_loss: -0.1888
# ae_loss: 0.0795
# ae_loss1: 0.0382
# ae_loss2: 0.0413
# cls_loss: 0.1003
# Saved state dicts!
# @iter: 31000: 1.0913 it/s
# d_loss: 0.7424
# g_loss: -0.1875
# ae_loss: 0.0806
# ae_loss1: 0.0388
# ae_loss2: 0.0418
# cls_loss: 0.1292
# Saved state dicts!
# @iter: 31100: 1.0650 it/s
# d_loss: 0.7478
# g_loss: -0.1883
# ae_loss: 0.0794
# ae_loss1: 0.0382
# ae_loss2: 0.0412
# cls_loss: 0.1016
# Saved state dicts!
# @iter: 31200: 1.0987 it/s
# d_loss: 0.7617
# g_loss: -0.2052
# ae_loss: 0.0802
# ae_loss1: 0.0386
# ae_loss2: 0.0416
# cls_loss: 0.0947
# Saved state dicts!
# test acc on clean examples (%): 90.04
# test acc on FGSM examples (%):  92.38
# test acc on BIM examples (%):   88.48
# test acc on EoT examples (%):   87.70
# test acc on BPDA examples (%):  88.28
# ________epoch 50________
# Saved state dicts!
# @iter: 31300: 0.4105 it/s
# d_loss: 0.7601
# g_loss: -0.2067
# ae_loss: 0.0796
# ae_loss1: 0.0383
# ae_loss2: 0.0413
# cls_loss: 0.1030
# Saved state dicts!
# @iter: 31400: 1.0949 it/s
# d_loss: 0.7626
# g_loss: -0.1964
# ae_loss: 0.0798
# ae_loss1: 0.0385
# ae_loss2: 0.0413
# cls_loss: 0.1080
# Saved state dicts!
# @iter: 31500: 1.0944 it/s
# d_loss: 0.7536
# g_loss: -0.1929
# ae_loss: 0.0803
# ae_loss1: 0.0387
# ae_loss2: 0.0416
# cls_loss: 0.1204
# Saved state dicts!
# @iter: 31600: 1.0603 it/s
# d_loss: 0.7526
# g_loss: -0.1871
# ae_loss: 0.0811
# ae_loss1: 0.0390
# ae_loss2: 0.0421
# cls_loss: 0.1162
# Saved state dicts!
# @iter: 31700: 1.0931 it/s
# d_loss: 0.7562
# g_loss: -0.2009
# ae_loss: 0.0799
# ae_loss1: 0.0385
# ae_loss2: 0.0414
# cls_loss: 0.1124
# Saved state dicts!
# @iter: 31800: 1.0949 it/s
# d_loss: 0.7460
# g_loss: -0.1877
# ae_loss: 0.0807
# ae_loss1: 0.0389
# ae_loss2: 0.0419
# cls_loss: 0.1007
# Saved state dicts!
# test acc on clean examples (%): 89.45
# test acc on FGSM examples (%):  91.02
# test acc on BIM examples (%):   87.70
# test acc on EoT examples (%):   87.89
# test acc on BPDA examples (%):  88.09
# ________epoch 51________
# Saved state dicts!
# @iter: 31900: 0.4107 it/s
# d_loss: 0.7441
# g_loss: -0.1774
# ae_loss: 0.0800
# ae_loss1: 0.0386
# ae_loss2: 0.0414
# cls_loss: 0.1195
# Saved state dicts!
# @iter: 32000: 1.0926 it/s
# d_loss: 0.7496
# g_loss: -0.1810
# ae_loss: 0.0797
# ae_loss1: 0.0381
# ae_loss2: 0.0416
# cls_loss: 0.1197
# Saved state dicts!
# @iter: 32100: 1.0717 it/s
# d_loss: 0.7600
# g_loss: -0.2077
# ae_loss: 0.0795
# ae_loss1: 0.0382
# ae_loss2: 0.0412
# cls_loss: 0.0995
# Saved state dicts!
# @iter: 32200: 1.0954 it/s
# d_loss: 0.7670
# g_loss: -0.2112
# ae_loss: 0.0801
# ae_loss1: 0.0386
# ae_loss2: 0.0414
# cls_loss: 0.1222
# Saved state dicts!
# @iter: 32400: 1.0948 it/s
# d_loss: 0.7599
# g_loss: -0.1935
# ae_loss: 0.0807
# ae_loss1: 0.0388
# ae_loss2: 0.0419
# cls_loss: 0.1109
# Saved state dicts!
# test acc on clean examples (%): 87.70
# test acc on FGSM examples (%):  89.45
# test acc on BIM examples (%):   85.94
# test acc on EoT examples (%):   84.38
# test acc on BPDA examples (%):  85.35
# ________epoch 52________
# Saved state dicts!
# @iter: 32500: 0.4126 it/s
# d_loss: 0.7568
# g_loss: -0.1965
# ae_loss: 0.0791
# ae_loss1: 0.0382
# ae_loss2: 0.0409
# cls_loss: 0.1239
# Saved state dicts!
# @iter: 32600: 1.0703 it/s
# d_loss: 0.7550
# g_loss: -0.1975
# ae_loss: 0.0791
# ae_loss1: 0.0382
# ae_loss2: 0.0410
# cls_loss: 0.0830
# Saved state dicts!
# @iter: 32700: 1.0950 it/s
# d_loss: 0.7597
# g_loss: -0.1975
# ae_loss: 0.0787
# ae_loss1: 0.0380
# ae_loss2: 0.0407
# cls_loss: 0.0889
# Saved state dicts!
# @iter: 32800: 1.0943 it/s
# d_loss: 0.7564
# g_loss: -0.1981
# ae_loss: 0.0802
# ae_loss1: 0.0387
# ae_loss2: 0.0415
# cls_loss: 0.1244
# Saved state dicts!
# @iter: 32900: 1.0956 it/s
# d_loss: 0.7492
# g_loss: -0.1972
# ae_loss: 0.0802
# ae_loss1: 0.0388
# ae_loss2: 0.0415
# cls_loss: 0.1199
# Saved state dicts!
# @iter: 33000: 1.0875 it/s
# d_loss: 0.7686
# g_loss: -0.2151
# ae_loss: 0.0799
# ae_loss1: 0.0385
# ae_loss2: 0.0414
# cls_loss: 0.1016
# Saved state dicts!
# @iter: 33100: 1.0672 it/s
# d_loss: 0.7701
# g_loss: -0.2233
# ae_loss: 0.0791
# ae_loss1: 0.0380
# ae_loss2: 0.0411
# cls_loss: 0.1221
# Saved state dicts!
# test acc on clean examples (%): 86.72
# test acc on FGSM examples (%):  89.65
# test acc on BIM examples (%):   84.77
# test acc on EoT examples (%):   83.98
# test acc on BPDA examples (%):  84.38
# ________epoch 53________
# Saved state dicts!
# @iter: 33200: 0.4093 it/s
# d_loss: 0.7600
# g_loss: -0.2015
# ae_loss: 0.0810
# ae_loss1: 0.0388
# ae_loss2: 0.0422
# cls_loss: 0.1127
# Saved state dicts!
# @iter: 33300: 1.0934 it/s
# d_loss: 0.7601
# g_loss: -0.1994
# ae_loss: 0.0797
# ae_loss1: 0.0384
# ae_loss2: 0.0413
# cls_loss: 0.1427
# Saved state dicts!
# @iter: 33400: 1.0935 it/s
# d_loss: 0.7638
# g_loss: -0.2142
# ae_loss: 0.0797
# ae_loss1: 0.0385
# ae_loss2: 0.0412
# cls_loss: 0.0885
# Saved state dicts!
# @iter: 33500: 1.0912 it/s
# d_loss: 0.7641
# g_loss: -0.2117
# ae_loss: 0.0789
# ae_loss1: 0.0381
# ae_loss2: 0.0408
# cls_loss: 0.0765
# Saved state dicts!
# @iter: 33600: 1.0690 it/s
# d_loss: 0.7643
# g_loss: -0.2118
# ae_loss: 0.0804
# ae_loss1: 0.0387
# ae_loss2: 0.0417
# cls_loss: 0.1233
# Saved state dicts!
# @iter: 33700: 1.0842 it/s
# d_loss: 0.7723
# g_loss: -0.2187
# ae_loss: 0.0796
# ae_loss1: 0.0383
# ae_loss2: 0.0413
# cls_loss: 0.1041
# Saved state dicts!
# test acc on clean examples (%): 85.16
# test acc on FGSM examples (%):  88.28
# test acc on BIM examples (%):   83.98
# test acc on EoT examples (%):   82.62
# test acc on BPDA examples (%):  82.23
# ________epoch 54________
# Saved state dicts!
# @iter: 33800: 0.4106 it/s
# d_loss: 0.7555
# g_loss: -0.1928
# ae_loss: 0.0786
# ae_loss1: 0.0378
# ae_loss2: 0.0407
# cls_loss: 0.1080
# Saved state dicts!
# @iter: 33900: 1.0861 it/s
# d_loss: 0.7558
# g_loss: -0.1961
# ae_loss: 0.0804
# ae_loss1: 0.0385
# ae_loss2: 0.0419
# cls_loss: 0.1295
# Saved state dicts!
# @iter: 34000: 1.0957 it/s
# d_loss: 0.7654
# g_loss: -0.2202
# ae_loss: 0.0793
# ae_loss1: 0.0382
# ae_loss2: 0.0412
# cls_loss: 0.1073
# Saved state dicts!
# @iter: 34100: 1.0665 it/s
# d_loss: 0.7704
# g_loss: -0.2207
# ae_loss: 0.0791
# ae_loss1: 0.0381
# ae_loss2: 0.0410
# cls_loss: 0.1051
# Saved state dicts!
# @iter: 34200: 1.0939 it/s
# d_loss: 0.7819
# g_loss: -0.2275
# ae_loss: 0.0793
# ae_loss1: 0.0382
# ae_loss2: 0.0410
# cls_loss: 0.0976
# Saved state dicts!
# @iter: 34300: 1.0926 it/s
# d_loss: 0.7748
# g_loss: -0.2221
# ae_loss: 0.0801
# ae_loss1: 0.0386
# ae_loss2: 0.0415
# cls_loss: 0.1062
# Saved state dicts!
# test acc on clean examples (%): 85.55
# test acc on FGSM examples (%):  88.67
# test acc on BIM examples (%):   84.57
# test acc on EoT examples (%):   84.38
# test acc on BPDA examples (%):  84.18
# ________epoch 55________
# Saved state dicts!
# @iter: 34400: 0.4101 it/s
# d_loss: 0.7670
# g_loss: -0.2168
# ae_loss: 0.0795
# ae_loss1: 0.0383
# ae_loss2: 0.0412
# cls_loss: 0.1010
# Saved state dicts!
# @iter: 34500: 1.0895 it/s
# d_loss: 0.7613
# g_loss: -0.2041
# ae_loss: 0.0792
# ae_loss1: 0.0380
# ae_loss2: 0.0412
# cls_loss: 0.1133
# Saved state dicts!
# @iter: 34600: 1.0900 it/s
# d_loss: 0.7535
# g_loss: -0.1959
# ae_loss: 0.0799
# ae_loss1: 0.0383
# ae_loss2: 0.0416
# cls_loss: 0.1087
# Saved state dicts!
# @iter: 34700: 1.0931 it/s
# d_loss: 0.7613
# g_loss: -0.2017
# ae_loss: 0.0802
# ae_loss1: 0.0385
# ae_loss2: 0.0417
# cls_loss: 0.1174
# Saved state dicts!
# @iter: 34800: 1.0835 it/s
# d_loss: 0.7569
# g_loss: -0.1871
# ae_loss: 0.0801
# ae_loss1: 0.0385
# ae_loss2: 0.0416
# cls_loss: 0.1343
# Saved state dicts!
# @iter: 34900: 1.0831 it/s
# d_loss: 0.7519
# g_loss: -0.1946
# ae_loss: 0.0793
# ae_loss1: 0.0382
# ae_loss2: 0.0411
# cls_loss: 0.0981
# Saved state dicts!
# test acc on clean examples (%): 88.87
# test acc on FGSM examples (%):  91.60
# test acc on BIM examples (%):   87.11
# test acc on EoT examples (%):   85.94
# test acc on BPDA examples (%):  85.16
# ________epoch 56________
# Saved state dicts!
# @iter: 35000: 0.4100 it/s
# d_loss: 0.7544
# g_loss: -0.1966
# ae_loss: 0.0785
# ae_loss1: 0.0380
# ae_loss2: 0.0405
# cls_loss: 0.0958
# Saved state dicts!
# Saved state dicts!
# @iter: 35100: 1.0644 it/s
# d_loss: 0.7638
# g_loss: -0.2150
# ae_loss: 0.0792
# ae_loss1: 0.0382
# ae_loss2: 0.0410
# cls_loss: 0.1048
# Saved state dicts!
# @iter: 35200: 1.2437 it/s
# d_loss: 0.7606
# g_loss: -0.2120
# ae_loss: 0.0803
# ae_loss1: 0.0387
# ae_loss2: 0.0416
# cls_loss: 0.1009
# Saved state dicts!
# @iter: 35300: 1.2413 it/s
# d_loss: 0.7582
# g_loss: -0.2058
# ae_loss: 0.0779
# ae_loss1: 0.0376
# ae_loss2: 0.0403
# cls_loss: 0.0860
# Saved state dicts!
# @iter: 35400: 1.2232 it/s
# d_loss: 0.7586
# g_loss: -0.2046
# ae_loss: 0.0795
# ae_loss1: 0.0383
# ae_loss2: 0.0412
# cls_loss: 0.1103
# Saved state dicts!
# @iter: 35500: 1.2328 it/s
# d_loss: 0.7512
# g_loss: -0.1849
# ae_loss: 0.0794
# ae_loss1: 0.0384
# ae_loss2: 0.0411
# cls_loss: 0.0975
# Saved state dicts!
# @iter: 35600: 1.1788 it/s
# d_loss: 0.7593
# g_loss: -0.2046
# ae_loss: 0.0789
# ae_loss1: 0.0381
# ae_loss2: 0.0409
# cls_loss: 0.0989
# Saved state dicts!
# test acc on clean examples (%): 86.52
# test acc on FGSM examples (%):  88.67
# test acc on BIM examples (%):   84.57
# test acc on EoT examples (%):   83.59
# test acc on BPDA examples (%):  84.18
# ________epoch 57________
# Saved state dicts!
# @iter: 35700: 0.4954 it/s
# d_loss: 0.7624
# g_loss: -0.2127
# ae_loss: 0.0795
# ae_loss1: 0.0384
# ae_loss2: 0.0411
# cls_loss: 0.1034
# Saved state dicts!
# @iter: 35800: 1.2232 it/s
# d_loss: 0.7659
# g_loss: -0.2089
# ae_loss: 0.0798
# ae_loss1: 0.0385
# ae_loss2: 0.0414
# cls_loss: 0.1026
# Saved state dicts!
# @iter: 35900: 1.2117 it/s
# d_loss: 0.7668
# g_loss: -0.2071
# ae_loss: 0.0803
# ae_loss1: 0.0386
# ae_loss2: 0.0417
# cls_loss: 0.1202
# Saved state dicts!
# @iter: 36000: 1.2473 it/s
# d_loss: 0.7598
# g_loss: -0.2029
# ae_loss: 0.0800
# ae_loss1: 0.0384
# ae_loss2: 0.0416
# cls_loss: 0.1016
# Saved state dicts!
# @iter: 36100: 1.1910 it/s
# d_loss: 0.7592
# g_loss: -0.2099
# ae_loss: 0.0799
# ae_loss1: 0.0386
# ae_loss2: 0.0413
# cls_loss: 0.1087
# Saved state dicts!
# @iter: 36200: 1.2304 it/s
# d_loss: 0.7625
# g_loss: -0.2073
# ae_loss: 0.0796
# ae_loss1: 0.0383
# ae_loss2: 0.0413
# cls_loss: 0.1308
# Saved state dicts!
# test acc on clean examples (%): 89.65
# test acc on FGSM examples (%):  91.99
# test acc on BIM examples (%):   88.48
# test acc on EoT examples (%):   87.89
# test acc on BPDA examples (%):  87.50
# ________epoch 58________
# Saved state dicts!
# @iter: 36300: 0.5018 it/s
# d_loss: 0.7562
# g_loss: -0.2017
# ae_loss: 0.0792
# ae_loss1: 0.0382
# ae_loss2: 0.0409
# cls_loss: 0.1024
# Saved state dicts!
# @iter: 36400: 1.2159 it/s
# d_loss: 0.7629
# g_loss: -0.2113
# ae_loss: 0.0803
# ae_loss1: 0.0385
# ae_loss2: 0.0418
# cls_loss: 0.0981
# Saved state dicts!
# @iter: 36500: 1.2403 it/s
# d_loss: 0.7649
# g_loss: -0.2128
# ae_loss: 0.0800
# ae_loss1: 0.0384
# ae_loss2: 0.0416
# cls_loss: 0.0985
# Saved state dicts!
# @iter: 36600: 1.2064 it/s
# d_loss: 0.7676
# g_loss: -0.2156
# ae_loss: 0.0788
# ae_loss1: 0.0379
# ae_loss2: 0.0409
# cls_loss: 0.1226
# Saved state dicts!
# @iter: 36800: 1.2388 it/s
# d_loss: 0.7733
# g_loss: -0.2157
# ae_loss: 0.0794
# ae_loss1: 0.0384
# ae_loss2: 0.0410
# cls_loss: 0.0925
# Saved state dicts!
# test acc on clean examples (%): 87.89
# test acc on FGSM examples (%):  86.91
# test acc on BIM examples (%):   86.91
# test acc on EoT examples (%):   85.74
# test acc on BPDA examples (%):  86.33
# ________epoch 59________
# Saved state dicts!
# @iter: 36900: 0.5012 it/s
# d_loss: 0.7627
# g_loss: -0.2035
# ae_loss: 0.0799
# ae_loss1: 0.0384
# ae_loss2: 0.0414
# cls_loss: 0.1006
# Saved state dicts!
# @iter: 37000: 1.2263 it/s
# d_loss: 0.7592
# g_loss: -0.2013
# ae_loss: 0.0787
# ae_loss1: 0.0379
# ae_loss2: 0.0408
# cls_loss: 0.1380
# Saved state dicts!
# @iter: 37100: 1.2009 it/s
# d_loss: 0.7639
# g_loss: -0.2128
# ae_loss: 0.0778
# ae_loss1: 0.0377
# ae_loss2: 0.0401
# cls_loss: 0.0788
# Saved state dicts!
# @iter: 37200: 1.2353 it/s
# d_loss: 0.7657
# g_loss: -0.2093
# ae_loss: 0.0791
# ae_loss1: 0.0382
# ae_loss2: 0.0409
# cls_loss: 0.0984
# Saved state dicts!
# @iter: 37300: 1.2241 it/s
# d_loss: 0.7609
# g_loss: -0.2070
# ae_loss: 0.0783
# ae_loss1: 0.0377
# ae_loss2: 0.0405
# cls_loss: 0.1178
# Saved state dicts!
# @iter: 37400: 1.2243 it/s
# d_loss: 0.7595
# g_loss: -0.2054
# ae_loss: 0.0784
# ae_loss1: 0.0378
# ae_loss2: 0.0406
# cls_loss: 0.0971
# Saved state dicts!
# test acc on clean examples (%): 87.11
# test acc on FGSM examples (%):  88.09
# test acc on BIM examples (%):   86.52
# test acc on EoT examples (%):   85.35
# test acc on BPDA examples (%):  85.55
# ________epoch 60________
# Saved state dicts!
# @iter: 37500: 0.5048 it/s
# d_loss: 0.7687
# g_loss: -0.2093
# ae_loss: 0.0786
# ae_loss1: 0.0379
# ae_loss2: 0.0407
# cls_loss: 0.1094
# Saved state dicts!
# @iter: 37600: 1.1892 it/s
# d_loss: 0.7697
# g_loss: -0.2086
# ae_loss: 0.0807
# ae_loss1: 0.0389
# ae_loss2: 0.0419
# cls_loss: 0.1408
# Saved state dicts!
# @iter: 37700: 1.1271 it/s
# d_loss: 0.7676
# g_loss: -0.2140
# ae_loss: 0.0800
# ae_loss1: 0.0385
# ae_loss2: 0.0415
# cls_loss: 0.0929
# Saved state dicts!
# @iter: 37800: 1.0843 it/s
# d_loss: 0.7672
# g_loss: -0.2148
# ae_loss: 0.0784
# ae_loss1: 0.0378
# ae_loss2: 0.0406
# cls_loss: 0.0982
# Saved state dicts!
# @iter: 37900: 1.0849 it/s
# d_loss: 0.7714
# g_loss: -0.2150
# ae_loss: 0.0783
# ae_loss1: 0.0378
# ae_loss2: 0.0404
# cls_loss: 0.0698
# Saved state dicts!
# @iter: 38000: 1.0836 it/s
# d_loss: 0.7715
# g_loss: -0.2121
# ae_loss: 0.0788
# ae_loss1: 0.0380
# ae_loss2: 0.0409
# cls_loss: 0.0975
# Saved state dicts!
# @iter: 38100: 1.0214 it/s
# d_loss: 0.7662
# g_loss: -0.2129
# ae_loss: 0.0794
# ae_loss1: 0.0383
# ae_loss2: 0.0411
# cls_loss: 0.1018
# Saved state dicts!
# test acc on clean examples (%): 88.48
# test acc on FGSM examples (%):  89.26
# test acc on BIM examples (%):   86.33
# test acc on EoT examples (%):   85.16
# test acc on BPDA examples (%):  85.55
# ________epoch 61________
# Saved state dicts!
# @iter: 38200: 0.4075 it/s
# d_loss: 0.7585
# g_loss: -0.2040
# ae_loss: 0.0787
# ae_loss1: 0.0379
# ae_loss2: 0.0408
# cls_loss: 0.1090
# Saved state dicts!
# @iter: 38300: 1.0858 it/s
# d_loss: 0.7590
# g_loss: -0.2019
# ae_loss: 0.0808
# ae_loss1: 0.0387
# ae_loss2: 0.0421
# cls_loss: 0.1130
# Saved state dicts!
# @iter: 38400: 1.1329 it/s
# d_loss: 0.7675
# g_loss: -0.2192
# ae_loss: 0.0796
# ae_loss1: 0.0385
# ae_loss2: 0.0411
# cls_loss: 0.1025
# Saved state dicts!
# @iter: 38500: 1.1515 it/s
# d_loss: 0.7633
# g_loss: -0.2120
# ae_loss: 0.0792
# ae_loss1: 0.0383
# ae_loss2: 0.0409
# cls_loss: 0.1098
# Saved state dicts!
# @iter: 38600: 1.0594 it/s
# d_loss: 0.7679
# g_loss: -0.2151
# ae_loss: 0.0793
# ae_loss1: 0.0383
# ae_loss2: 0.0410
# cls_loss: 0.1141
# Saved state dicts!
# @iter: 38700: 1.0911 it/s
# d_loss: 0.7607
# g_loss: -0.2064
# ae_loss: 0.0791
# ae_loss1: 0.0380
# ae_loss2: 0.0411
# cls_loss: 0.1075
# Saved state dicts!
# test acc on clean examples (%): 88.28
# test acc on FGSM examples (%):  90.82
# test acc on BIM examples (%):   87.30
# test acc on EoT examples (%):   86.13
# test acc on BPDA examples (%):  85.74
# ________epoch 62________
# Saved state dicts!
# @iter: 38800: 0.4085 it/s
# d_loss: 0.7688
# g_loss: -0.2227
# ae_loss: 0.0784
# ae_loss1: 0.0378
# ae_loss2: 0.0405
# cls_loss: 0.1055
# Saved state dicts!
# @iter: 38900: 1.0732 it/s
# d_loss: 0.7643
# g_loss: -0.2093
# ae_loss: 0.0796
# ae_loss1: 0.0383
# ae_loss2: 0.0413
# cls_loss: 0.1045
# Saved state dicts!
# @iter: 39000: 1.0791 it/s
# d_loss: 0.7714
# g_loss: -0.2131
# ae_loss: 0.0794
# ae_loss1: 0.0382
# ae_loss2: 0.0411
# cls_loss: 0.0880
# Saved state dicts!
# @iter: 39100: 1.0590 it/s
# d_loss: 0.7634
# g_loss: -0.2098
# ae_loss: 0.0792
# ae_loss1: 0.0381
# ae_loss2: 0.0411
# cls_loss: 0.0940
# Saved state dicts!
# @iter: 39200: 1.0852 it/s
# d_loss: 0.7643
# g_loss: -0.2081
# ae_loss: 0.0800
# ae_loss1: 0.0386
# ae_loss2: 0.0414
# cls_loss: 0.1215
# Saved state dicts!
# @iter: 39300: 1.0928 it/s
# d_loss: 0.7642
# g_loss: -0.2167
# ae_loss: 0.0789
# ae_loss1: 0.0381
# ae_loss2: 0.0408
# cls_loss: 0.0921
# Saved state dicts!
# test acc on clean examples (%): 91.02
# test acc on FGSM examples (%):  91.60
# test acc on BIM examples (%):   89.06
# test acc on EoT examples (%):   88.28
# test acc on BPDA examples (%):  88.09
# ________epoch 63________
# Saved state dicts!
# @iter: 39400: 0.4157 it/s
# d_loss: 0.7635
# g_loss: -0.2140
# ae_loss: 0.0787
# ae_loss1: 0.0380
# ae_loss2: 0.0407
# cls_loss: 0.0881
# Saved state dicts!
# @iter: 39500: 1.1083 it/s
# d_loss: 0.7646
# g_loss: -0.2124
# ae_loss: 0.0782
# ae_loss1: 0.0377
# ae_loss2: 0.0405
# cls_loss: 0.0816
# Saved state dicts!
# @iter: 39600: 1.0281 it/s
# d_loss: 0.7655
# g_loss: -0.2111
# ae_loss: 0.0802
# ae_loss1: 0.0385
# ae_loss2: 0.0417
# cls_loss: 0.1143
# Saved state dicts!
# @iter: 39700: 1.0732 it/s
# d_loss: 0.7661
# g_loss: -0.2178
# ae_loss: 0.0795
# ae_loss1: 0.0384
# ae_loss2: 0.0411
# cls_loss: 0.0753
# Saved state dicts!
